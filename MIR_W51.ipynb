# %% [markdown]
# # Mid-infrared polarimetry: a Bayesian approach

# %% [markdown]
# The aim of this code is to develop a Bayesian approach to infere the absorptive and emissive componets of a given observations. In this case the observations are those of W51 IRS extracted from Aitken et al. (2000, MNRAS, 348, 279), fig. 2.

# %%
# %matplotlib inline
import os
from pymc3 import  *
from pymc3.stats import *
import numpy as np
import matplotlib.pyplot as plt
from readcol import readcol
import patsy
import theano
from pandas import *
from statsmodels.formula.api import glm as glm_sm
import statsmodels.api as s
import numpy as np
from scipy import stats

# %% [markdown]
# ##### Reading BN data to model the absorptive and emissive components

# %% [markdown]
# The absorptive and emissive componets were extracted from fig. 1 in Aitken et al. ^2000, MNRAS, 348, 279)

# %%
### Observations
#BN absorptive component use for modeling from Aitken+04 (MNRAS, 348, 279)
l_bn,fa_bn=readcol("BN_fa.dat",twod=False)
l_bn,fe_bn=readcol("BN_fe.dat",twod=False)

#Assumed extintion Rv=5.5 from Draine:  
#ftp://ftp.astro.princeton.edu/draine/dust/mix/kext_albedo_WD_MW_5.5A_30_D03.all
l_ext,tau_ext=readcol("ext_Rv55.dat",twod=False)

#BN emissive component use for modeling
#fe_bn = fa_bn/tau_ext
#fe_bn = fe_bn/max(fe_bn)

###############
### Figures ###
###############
font_size=6.0
label_size=6.
lw = 3.
fig,(ax1) = plt.subplots(1,1,figsize=(7,4),dpi=120)

#Model
ax1.plot(l_bn,fa_bn,color='black',lw=lw,label='Absorptive component')
ax1.plot(l_bn,fe_bn,color='black',lw=lw,linestyle='-.',label='Emissive component')

ax1.set_xlabel('Wavelength ($\mu$m)')
ax1.set_ylabel('Normalized polarization')
ax1.set_ylim([0,1])
ax1.set_xlim([7,13])
ax1.legend(loc='best')

## Save Fig. to PDF and display
plt.savefig('model.pdf')
#os.system('open model.pdf')
# Out:
# Removing 1 rows that don't match most common length 2.
# 25 rows read into array.
# Removing 8 rows that don't match most common length 2.
# 25 rows read into array.

# %% [markdown]
# ##### Reading the W51 IRS spectroscopic observations

# %% [markdown]
# Data from Aitken et al. (2000, MNRAS, 348, 279). This data is used to compare with the results from their paper.

# %%
### Observations

#W51 IRS observations
l_w51,q_w51=readcol("W51_q.dat",twod=False)
l_w51,qerr_w51=readcol("W51_qerr.dat",twod=False)
l_w51,u_w51=readcol("W51_u.dat",twod=False)
l_w51,uerr_w51=readcol("W51_uerr.dat",twod=False)

#Transform input data in 
qerr_w51 = qerr_w51 - q_w51
uerr_w51 = uerr_w51 - u_w51

q_obs = q_w51 
u_obs = u_w51
qerr_obs = qerr_w51 
uerr_obs = uerr_w51
l_obs = l_w51

p_obs   = 100.*np.sqrt(q_obs*q_obs + u_obs*u_obs)
perr_obs = 100.*np.sqrt((q_obs+qerr_obs)*(q_obs+qerr_obs) + (u_obs+uerr_obs)*(u_obs+uerr_obs)) - p_obs 

pa_obs   = 0.5*np.arctan(u_obs/q_obs)*180./3.1415 
pa_err_obs   = 0.5*np.arctan((u_obs+uerr_obs)/(q_obs+qerr_obs))*180./3.1415 - pa_obs
####

###############
### Figures ###
###############
font_size=6.0
label_size=6.
lw = 3.
fig,(ax1,ax2,ax3,ax4) = plt.subplots(1,4,figsize=(25.0,5.),dpi=120)

#Imaging data
ax1.errorbar(l_obs,q_obs,yerr=qerr_obs,fmt='o',label='q',color='blue')

#q
ax1.set_xlabel('Wavelength ($\mu$m)')
ax1.set_ylabel('q')
ax1.set_ylim([-0.05,0.05])
ax1.set_xlim([7,14])
ax1.legend(loc='best')

#u
ax2.errorbar(l_obs,u_obs,yerr=uerr_obs,fmt='o',label='u',color='blue')

ax2.set_xlabel('Wavelength ($\mu$m)')
ax2.set_ylabel('u')
ax2.set_ylim([-0.05,0.05])
ax2.set_xlim([7,14])
ax2.legend(loc='best')

#p
ax3.errorbar(l_obs,p_obs,yerr=perr_obs,fmt='o',label='P',color='blue')

ax3.set_xlabel('Wavelength ($\mu$m)')
ax3.set_ylabel('Degree of polarization')
ax3.set_ylim([0,10])
ax3.set_xlim([7,14])
ax3.legend(loc='best')

#pa
ax4.errorbar(l_obs,pa_obs,yerr=pa_err_obs,fmt='o',label='PA',color='blue')

ax4.set_xlabel('Wavelength ($\mu$m)')
ax4.set_ylabel('P.A. of polarization')
ax4.set_ylim([-90,90])
ax4.set_xlim([7,14])
ax4.legend(loc='best')
# Out:
# Removing 1 rows that don't match most common length 2.
# 25 rows read into array.
# Removing 1 rows that don't match most common length 2.
# 25 rows read into array.
# Removing 1 rows that don't match most common length 2.
# 25 rows read into array.
# Removing 1 rows that don't match most common length 2.
# 25 rows read into array.

# %% [markdown]
# ##### Inference Model

# %%
#The aim is to fit q and u (as shown in the above plots) using the following linear combination 
#of 4 independent parameters (A,B,C,D) and 2 already known empirical functions (fa, fe).
#q = A*fa*lambda + B*fe*lambda
#u = C*fa*lambda + D*fe*lambda

#Boundaries of A,B,C,D factors by n_minmax time to the min. and max. of q and u.
n_minmax = 5
qmin = min(q_obs)
umin = min(u_obs)
if umin < 0: 
    u_lower = umin + n_minmax*umin
else:
    u_lower = qmin - n_minmax*umin
if qmin < 0:
    q_lower = umin + n_minmax*qmin
else:
    q_lower = qmin - n_minmax*qmin
    
q_upper = max(q_obs) + n_minmax*max(q_obs)
u_upper = max(u_obs) + n_minmax*max(u_obs)
        
#Built the model
with Model() as hierarchical_model:
    #Variables are Uniform functions with width equal to 5 x std(q,u)
    A  = Uniform('A',lower=q_lower,upper=q_upper)
    B  = Uniform('B',lower=q_lower,upper=q_upper)
    C  = Uniform('C',lower=u_lower,upper=u_upper)
    D  = Uniform('D',lower=u_lower,upper=u_upper)
    #Deterministic model. Dependence of variables
    qa = A*fa_bn*l_bn
    qe = B*fe_bn*l_bn
    ua = C*fa_bn*l_bn
    ue = D*fe_bn*l_bn
    q_fit = qa + qe
    u_fit = ua + ue
    # Data likelihood. Normal distributions per each observable (data point per wavelength) 
    #with stdv the error of each data point from the observations.
    q_like  = Normal('q', mu=q_fit, sd=qerr_obs, observed=q_obs) 
    u_like  = Normal('u', mu=u_fit, sd=uerr_obs, observed=u_obs)  

with hierarchical_model:    
    #Inference
    start = find_MAP()
    step = NUTS([A,B,C,D,q_like,u_like],scaling=start)
    # draw n_post posterior samples using NUTS sampling
    n_post = 25000
    hierarchical_trace = sample(n_post, step, start=start)
# Out:
#  [                  0%                  ] 103 of 25000 complete in 0.5 sec
#  [                  1%                  ] 317 of 25000 complete in 1.0 sec
#  [                  2%                  ] 557 of 25000 complete in 1.5 sec
#  [-                 3%                  ] 790 of 25000 complete in 2.0 sec
#  [-                 4%                  ] 1055 of 25000 complete in 2.5 sec
#  [--                5%                  ] 1317 of 25000 complete in 3.0 sec
#  [--                6%                  ] 1583 of 25000 complete in 3.5 sec
#  [--                7%                  ] 1860 of 25000 complete in 4.0 sec
#  [---               8%                  ] 2114 of 25000 complete in 4.5 sec
#  [---               9%                  ] 2389 of 25000 complete in 5.0 sec
#  [----             10%                  ] 2668 of 25000 complete in 5.5 sec
#  [----             11%                  ] 2933 of 25000 complete in 6.0 sec
#  [----             12%                  ] 3218 of 25000 complete in 6.5 sec
#  [-----            13%                  ] 3478 of 25000 complete in 7.0 sec
#  [-----            14%                  ] 3732 of 25000 complete in 7.5 sec
#  [------           16%                  ] 4014 of 25000 complete in 8.0 sec
#  [------           17%                  ] 4298 of 25000 complete in 8.5 sec
#  [------           18%                  ] 4560 of 25000 complete in 9.0 sec
#  [-------          19%                  ] 4809 of 25000 complete in 9.5 sec
#  [-------          20%                  ] 5074 of 25000 complete in 10.0 sec
#  [--------         21%                  ] 5339 of 25000 complete in 10.5 sec
#  [--------         22%                  ] 5632 of 25000 complete in 11.0 sec
#  [--------         23%                  ] 5878 of 25000 complete in 11.5 sec
#  [---------        24%                  ] 6163 of 25000 complete in 12.0 sec
#  [---------        25%                  ] 6429 of 25000 complete in 12.5 sec
#  [----------       26%                  ] 6699 of 25000 complete in 13.0 sec
#  [----------       27%                  ] 6976 of 25000 complete in 13.5 sec
#  [-----------      28%                  ] 7243 of 25000 complete in 14.0 sec
#  [-----------      30%                  ] 7501 of 25000 complete in 14.5 sec
#  [-----------      31%                  ] 7785 of 25000 complete in 15.0 sec
#  [------------     32%                  ] 8058 of 25000 complete in 15.5 sec
#  [------------     33%                  ] 8329 of 25000 complete in 16.0 sec
#  [-------------    34%                  ] 8589 of 25000 complete in 16.5 sec
#  [-------------    35%                  ] 8854 of 25000 complete in 17.0 sec
#  [-------------    36%                  ] 9115 of 25000 complete in 17.5 sec
#  [--------------   37%                  ] 9387 of 25000 complete in 18.0 sec
#  [--------------   38%                  ] 9657 of 25000 complete in 18.6 sec
#  [---------------  39%                  ] 9914 of 25000 complete in 19.1 sec
#  [---------------  40%                  ] 10183 of 25000 complete in 19.6 sec
#  [---------------  41%                  ] 10455 of 25000 complete in 20.1 sec
#  [---------------- 42%                  ] 10744 of 25000 complete in 20.6 sec
#  [---------------- 44%                  ] 11030 of 25000 complete in 21.1 sec
#  [-----------------45%                  ] 11301 of 25000 complete in 21.6 sec
#  [-----------------46%                  ] 11565 of 25000 complete in 22.1 sec
#  [-----------------47%                  ] 11852 of 25000 complete in 22.6 sec
#  [-----------------48%                  ] 12129 of 25000 complete in 23.1 sec
#  [-----------------49%                  ] 12412 of 25000 complete in 23.6 sec
#  [-----------------50%                  ] 12679 of 25000 complete in 24.1 sec
#  [-----------------51%                  ] 12979 of 25000 complete in 24.6 sec
#  [-----------------53%                  ] 13259 of 25000 complete in 25.1 sec
#  [-----------------54%                  ] 13548 of 25000 complete in 25.6 sec
#  [-----------------55%                  ] 13811 of 25000 complete in 26.1 sec
#  [-----------------56%-                 ] 14092 of 25000 complete in 26.6 sec
#  [-----------------57%-                 ] 14350 of 25000 complete in 27.1 sec
#  [-----------------58%--                ] 14640 of 25000 complete in 27.6 sec
#  [-----------------59%--                ] 14909 of 25000 complete in 28.1 sec
#  [-----------------60%---               ] 15212 of 25000 complete in 28.6 sec
#  [-----------------61%---               ] 15489 of 25000 complete in 29.1 sec
#  [-----------------63%---               ] 15776 of 25000 complete in 29.6 sec
#  [-----------------64%----              ] 16038 of 25000 complete in 30.1 sec
#  [-----------------65%----              ] 16321 of 25000 complete in 30.6 sec
#  [-----------------66%-----             ] 16586 of 25000 complete in 31.1 sec
#  [-----------------67%-----             ] 16884 of 25000 complete in 31.6 sec
#  [-----------------68%------            ] 17166 of 25000 complete in 32.1 sec
#  [-----------------69%------            ] 17446 of 25000 complete in 32.6 sec
#  [-----------------71%------            ] 17751 of 25000 complete in 33.1 sec
#  [-----------------72%-------           ] 18016 of 25000 complete in 33.6 sec
#  [-----------------73%-------           ] 18292 of 25000 complete in 34.1 sec
#  [-----------------74%--------          ] 18566 of 25000 complete in 34.6 sec
#  [-----------------75%--------          ] 18815 of 25000 complete in 35.1 sec
#  [-----------------76%--------          ] 19074 of 25000 complete in 35.6 sec
#  [-----------------77%---------         ] 19343 of 25000 complete in 36.1 sec
#  [-----------------78%---------         ] 19630 of 25000 complete in 36.6 sec
#  [-----------------79%----------        ] 19886 of 25000 complete in 37.1 sec
#  [-----------------80%----------        ] 20184 of 25000 complete in 37.6 sec
#  [-----------------81%-----------       ] 20457 of 25000 complete in 38.1 sec
#  [-----------------82%-----------       ] 20718 of 25000 complete in 38.6 sec
#  [-----------------83%-----------       ] 20990 of 25000 complete in 39.1 sec
#  [-----------------85%------------      ] 21278 of 25000 complete in 39.6 sec
#  [-----------------86%------------      ] 21569 of 25000 complete in 40.1 sec
#  [-----------------87%-------------     ] 21854 of 25000 complete in 40.6 sec
#  [-----------------88%-------------     ] 22139 of 25000 complete in 41.1 sec
#  [-----------------89%--------------    ] 22433 of 25000 complete in 41.6 sec
#  [-----------------90%--------------    ] 22729 of 25000 complete in 42.1 sec
#  [-----------------92%--------------    ] 23005 of 25000 complete in 42.6 sec
#  [-----------------93%---------------   ] 23255 of 25000 complete in 43.1 sec
#  [-----------------94%---------------   ] 23514 of 25000 complete in 43.6 sec
#  [-----------------95%----------------  ] 23778 of 25000 complete in 44.1 sec
#  [-----------------96%----------------  ] 24017 of 25000 complete in 44.6 sec
#  [-----------------97%----------------  ] 24279 of 25000 complete in 45.1 sec
#  [-----------------98%----------------- ] 24549 of 25000 complete in 45.6 sec
#  [-----------------99%----------------- ] 24821 of 25000 complete in 46.1 sec
#  [-----------------100%-----------------] 25000 of 25000 complete in 46.5 sec

# %%
#############
### PLOTS ###
#############
#Remove the first n_steps from the trace
n_steps = 5000
#Plots of the posteriors and trace to check convergence beyond n_step.
traceplot(hierarchical_trace[n_steps:],['A','B','C','D']);

# %%
summary(hierarchical_trace[n_steps:],['A','B','C','D'])
# Out:
# A:
#
#   Mean             SD               MC Error         95% HPD interval
#   -------------------------------------------------------------------
#
#   0.001            0.000            0.000            [0.000, 0.001]
#
#   Posterior quantiles:
#   2.5            25             50             75             97.5
#   |--------------|==============|==============|--------------|
#
#   0.000          0.000          0.001          0.001          0.001
#
#
# B:
#
#   Mean             SD               MC Error         95% HPD interval
#   -------------------------------------------------------------------
#
#   0.001            0.000            0.000            [0.000, 0.001]
#
#   Posterior quantiles:
#   2.5            25             50             75             97.5
#   |--------------|==============|==============|--------------|
#
#   0.000          0.000          0.001          0.001          0.001
#
#
# C:
#
#   Mean             SD               MC Error         95% HPD interval
#   -------------------------------------------------------------------
#
#   -0.006           0.000            0.000            [-0.006, -0.005]
#
#   Posterior quantiles:
#   2.5            25             50             75             97.5
#   |--------------|==============|==============|--------------|
#
#   -0.006         -0.006         -0.006         -0.006         -0.005
#
#
# D:
#
#   Mean             SD               MC Error         95% HPD interval
#   -------------------------------------------------------------------
#
#   0.003            0.000            0.000            [0.002, 0.003]
#
#   Posterior quantiles:
#   2.5            25             50             75             97.5
#   |--------------|==============|==============|--------------|
#
#   0.002          0.003          0.003          0.003          0.003

# %% [markdown]
# ##### Posteriors and fitting

# %%
#Data from trace to dataframe using pandas
df_trace = trace_to_dataframe(hierarchical_trace[n_steps:])

################
### Best fit ###
################
A_m     = stats.mode(df_trace['A'])[0]
B_m     = stats.mode(df_trace['B'])[0]
C_m     = stats.mode(df_trace['C'])[0]
D_m     = stats.mode(df_trace['D'])[0]

fa = fa_bn*l_bn
fe = fe_bn*l_bn

qa_bestfit = A_m*fa
qe_bestfit = B_m*fe
q_bestfit = qa_bestfit + qe_bestfit

ua_bestfit = C_m*fa
ue_bestfit = D_m*fe
u_bestfit = ua_bestfit + ue_bestfit


p_bestfit  = 100.*np.sqrt(q_bestfit*q_bestfit + u_bestfit*u_bestfit)
p_a_bestfit = 100.*np.sqrt(qa_bestfit*qa_bestfit + ua_bestfit*ua_bestfit) 
p_e_bestfit = 100.*np.sqrt(qe_bestfit*qe_bestfit + ue_bestfit*ue_bestfit) 

pa_bestfit   = 0.5*np.arctan(u_bestfit/q_bestfit)*180./3.1415 
pa_a_bestfit = 0.5*np.arctan(ua_bestfit/qa_bestfit)*180./3.1415 + zeros(len(l_bn))
pa_e_bestfit = 0.5*np.arctan(ue_bestfit/qe_bestfit)*180./3.1415 + zeros(len(l_bn))


##################
### Posteriors ###
##################
A_max = hpd(hierarchical_trace['A'])[1]
A_min = hpd(hierarchical_trace['A'])[0]
B_max = hpd(hierarchical_trace['B'])[1]
B_min = hpd(hierarchical_trace['B'])[0]
C_max = hpd(hierarchical_trace['C'])[1]
C_min = hpd(hierarchical_trace['C'])[0]
D_max = hpd(hierarchical_trace['D'])[1]
D_min = hpd(hierarchical_trace['D'])[0]


###############
### Figures ###
###############
font_size=50.0
label_size=50.
lw_components = 2.
lw_trace = 1.
ll = l_bn
fig,(ax1,ax2,ax3,ax4) = plt.subplots(1,4,figsize=(20.0,4.),dpi=120)

for ii in range(0,2000):
    qa = df_trace.A[ii] * fa 
    qe = df_trace.B[ii] * fe
    q = qa + qe
    ax1.plot(ll,q,lw=lw_trace,color='red',alpha=.01)

    ua = df_trace.C[ii] * fa 
    ue = df_trace.D[ii] * fe
    u = ua + ue
    ax2.plot(ll,u,lw=lw_trace,color='red',alpha=.01)
    
    p = 100*np.sqrt(q*q + u*u)
    ax3.plot(ll,p,lw=lw_trace,color='red',alpha=.01)
    
    pa = 0.5*np.arctan(u/q)*180./3.1592
    ax4.plot(ll,pa,lw=lw_trace,color='red',alpha=.01)

#q
ax1.errorbar(l_obs,q_obs,yerr=qerr_obs,fmt='o',label='W51',color='blue')
ax1.plot(ll,q_bestfit,lw=lw_components,color='black',label='Model: total')
ax1.plot(ll,qa_bestfit,lw=lw_components,color='black',linestyle='-.',label='Model: absorptive component')
ax1.plot(ll,qe_bestfit,lw=lw_components,color='black',linestyle=':',label='Model: emissive component')

ax1.set_xlabel('Wavelength ($\mu$m)')
ax1.set_ylabel('q')
ax1.set_ylim([-0.07,0.07])
ax1.set_xlim([7,14])


#u
ax2.errorbar(l_obs,u_obs,yerr=uerr_obs,fmt='o',label='W51',color='blue')
ax2.plot(ll,u_bestfit,lw=lw_components,color='black',label='Model: total')
ax2.plot(ll,ua_bestfit,lw=lw_components,color='black',linestyle='-.',label='Model: absorptive component')
ax2.plot(ll,ue_bestfit,lw=lw_components,color='black',linestyle=':',label='Model: emissive component')


ax2.set_xlabel('Wavelength ($\mu$m)')
ax2.set_ylabel('u')
ax2.set_ylim([-0.07,0.07])
ax2.set_xlim([7,14])

#p
ax3.errorbar(l_obs,p_obs,yerr=perr_obs,fmt='o',label='W51',color='blue')
ax3.plot(ll,p_bestfit,lw=lw_components,color='black',label='Model: total')
ax3.plot(ll,p_a_bestfit,lw=lw_components,color='black',linestyle='-.',label='Model: absorptive component')
ax3.plot(ll,p_e_bestfit,lw=lw_components,color='black',linestyle=':',label='Model: emissive component')


ax3.set_xlabel('Wavelength ($\mu$m)')
ax3.set_ylabel('Degree of polarization (%)')
ax3.set_ylim([0,8])
ax3.set_xlim([7,14])

#pa
ax4.errorbar(l_obs,pa_obs,yerr=pa_err_obs,fmt='o',label='W51',color='blue')
ax4.plot(ll,pa_bestfit,lw=lw_components,color='black',label='Total Model')
ax4.plot(ll,pa_a_bestfit,lw=lw_components,color='black',linestyle='-.',label='absorptive component')
ax4.plot(ll,pa_e_bestfit,lw=lw_components,color='black',linestyle=':',label='emissive component')

ax4.set_xlabel('Wavelength ($\mu$m)')
ax4.set_ylabel('P.A. of polarization')
ax4.set_ylim([-90,90])
ax4.set_xlim([7,14])

ax1.legend(loc='lower left')


## Save Fig. to PDF and display
plt.savefig('W51_model.pdf')
os.system('open W51_model.pdf')
# Out:
# 0
