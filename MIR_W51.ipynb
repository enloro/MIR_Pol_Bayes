# %% [markdown]
# # Dichroic polarization at mid-infrared wavelengths: a Bayesian approach

# %% [markdown]
# The aim of this code is to develop a Bayesian approach to infere the absorptive and emissive componets of a given observations. In this case the observations are those of W51 IRS extracted from Smith et al. (2000, MNRAS, 312, 327), fig. 2.

# %%
# %matplotlib inline
import os
from pylab import *
from pymc3 import  *
from pymc3.stats import *
import numpy as np
import matplotlib.pyplot as plt
from readcol import readcol
import patsy
import theano
from pandas import *
from statsmodels.formula.api import glm as glm_sm
import statsmodels.api as s
import numpy as np
from scipy import stats

# %% [markdown]
# ##### Reading BN data to model the absorptive and emissive components

# %% [markdown]
# The absorptive and emissive componets were extracted from fig. 1 in Smith et al. (2000, MNRAS, 312, 327)

# %%
#At this stage of the modeling the appropiate absorptive/emissive polarization components can be introduced.
#The user can introduce their own customized dichroic compoents based on a specific dust composition,
#or if silicate-like grains are used then the user can simply use the default dichroic components
#supplied by this model.

#In the case the user want to use diferent extinction curve,
#the extinction curve of Rv=5.5 by Draine and collaborators can be used, extracted from
#ftp://ftp.astro.princeton.edu/draine/dust/mix/kext_albedo_WD_MW_5.5A_30_D03.all
#l_ext,tau_ext=readcol("ext_Rv55.dat",twod=False)

#Then the emissive and absorptive componets can be written as:
#fe_bn = fa_bn/tau_ext
#fe_bn = fe_bn/max(fe_bn)


### Observations
#BN absorptive component use for modeling from Smith et al. (2000, MNRAS, 312, 327) & Aitken+04 (MNRAS, 348, 279) 
l_bn,fa_bn=readcol("BN_fa.dat",twod=False)
l_bn,fe_bn=readcol("BN_fe.dat",twod=False)



###############
### Figures ###
###############
font_size=15.0
label_size=10.
lw = 3.
fig,(ax1) = plt.subplots(1,1,figsize=(7,4),dpi=120)

#Model
ax1.plot(l_bn,fa_bn,color='black',lw=lw,label='Absorptive component')
ax1.plot(l_bn,fe_bn,color='black',lw=lw,linestyle='-.',label='Emissive component')

ax1.set_xlabel('Wavelength ($\mu$m)',fontsize=font_size)
ax1.set_ylabel('Normalized polarization',fontsize=font_size)
ax1.set_ylim([0,1])
ax1.set_xlim([7,13])
ax1.xaxis.set_tick_params(labelsize=font_size)
ax1.yaxis.set_tick_params(labelsize=font_size)
ax1.legend(loc='best')

## Save Fig. to PDF and display
plt.savefig('model.pdf')
#os.system('open model.pdf')
# Out:
# Removing 1 rows that don't match most common length 2.
# 25 rows read into array.

# %% [markdown]
# ##### Reading the W51 IRS spectroscopic observations

# %% [markdown]
# Data from Aitken et al. (2000, MNRAS, 348, 279). This data is used to compare with the results from their paper.

# %%
### Observations

#W51 IRS observations
l_w51,q_w51=readcol("W51_q.dat",twod=False)
l_w51,qerr_w51=readcol("W51_qerr.dat",twod=False)
l_w51,u_w51=readcol("W51_u.dat",twod=False)
l_w51,uerr_w51=readcol("W51_uerr.dat",twod=False)

#Transform input data in 
qerr_w51 = qerr_w51 - q_w51
uerr_w51 = uerr_w51 - u_w51

q_obs = q_w51 
u_obs = u_w51
qerr_obs = qerr_w51 
uerr_obs = uerr_w51
l_obs = l_w51

p_obs   = 100.*np.sqrt(q_obs*q_obs + u_obs*u_obs)
perr_obs = 100.*np.sqrt((q_obs+qerr_obs)*(q_obs+qerr_obs) + (u_obs+uerr_obs)*(u_obs+uerr_obs)) - p_obs 

pa_obs   = 0.5*np.arctan(u_obs/q_obs)*180./3.1415 
pa_err_obs   = 0.5*np.arctan((u_obs+uerr_obs)/(q_obs+qerr_obs))*180./3.1415 - pa_obs
####



###############
### Figures ###
###############
font_size=6.0
label_size=6.
lw = 3.
fig,(ax1,ax2,ax3,ax4) = plt.subplots(1,4,figsize=(25.0,5.),dpi=120)

#q
ax1.errorbar(l_obs,q_obs,yerr=qerr_obs,fmt='o',label='q',color='blue')

ax1.set_xlabel('Wavelength ($\mu$m)')
ax1.set_ylabel('q')
ax1.set_ylim([-0.05,0.05])
ax1.set_xlim([7,14])
ax1.legend(loc='best')

#u
ax2.errorbar(l_obs,u_obs,yerr=uerr_obs,fmt='o',label='u',color='blue')

ax2.set_xlabel('Wavelength ($\mu$m)')
ax2.set_ylabel('u')
ax2.set_ylim([-0.05,0.05])
ax2.set_xlim([7,14])
ax2.legend(loc='best')

#p
ax3.errorbar(l_obs,p_obs,yerr=perr_obs,fmt='o',label='P',color='blue')

ax3.set_xlabel('Wavelength ($\mu$m)')
ax3.set_ylabel('Degree of polarization')
ax3.set_ylim([0,10])
ax3.set_xlim([7,14])
ax3.legend(loc='best')

#pa
ax4.errorbar(l_obs,pa_obs,yerr=pa_err_obs,fmt='o',label='PA',color='blue')


ax4.set_xlabel('Wavelength ($\mu$m)')
ax4.set_ylabel('P.A. of polarization')
ax4.set_ylim([-90,90])
ax4.set_xlim([7,14])
ax4.legend(loc='best')
# Out:
# Removing 1 rows that don't match most common length 2.
# 25 rows read into array.
# Removing 1 rows that don't match most common length 2.
# 25 rows read into array.
# Removing 1 rows that don't match most common length 2.
# 25 rows read into array.
# Removing 1 rows that don't match most common length 2.
# 25 rows read into array.

# %% [markdown]
# ##### Inference Model

# %%
#The aim is to infer q and u (as shown in the above plots) using the linear combination 
#of 4 independent parameters (A,B,C,D) and 2 already known empirical functions (fa, fe).
#q = A*fa*lambda + B*fe*lambda
#u = C*fa*lambda + D*fe*lambda

#Boundaries of A,B,C,D factors by n_minmax time to the min. and max. of the observables q and u.
n_minmax = 5
qmin = min(q_obs)
umin = min(u_obs)
if umin < 0: 
    u_lower = umin + n_minmax*umin
else:
    u_lower = umin - n_minmax*umin
if qmin < 0:
    q_lower = qmin + n_minmax*qmin
else:
    q_lower = qmin - n_minmax*qmin

qmax = max(q_obs)
umax = max(u_obs)
if umax < 0: 
    u_upper = umax - n_minmax*umax
else:
    u_upper = umax + n_minmax*umax
if qmax < 0:
    q_upper = qmax - n_minmax*qmax
else:
    q_upper = qmax + n_minmax*qmax
    
    
#Built the model
with Model() as model:
    #Variables are Uniform functions with width equal to 5 x std(q,u)
    A  = Uniform('A',lower=q_lower,upper=q_upper)
    B  = Uniform('B',lower=q_lower,upper=q_upper)
    C  = Uniform('C',lower=u_lower,upper=u_upper)
    D  = Uniform('D',lower=u_lower,upper=u_upper)
    #Deterministic model. Dependence of variables
    qa = A*fa_bn*l_obs
    qe = B*fe_bn*l_obs
    ua = C*fa_bn*l_obs
    ue = D*fe_bn*l_obs
    q_fit = qa + qe
    u_fit = ua + ue
    # Data likelihood. Normal distributions per each observable (data point per wavelength) 
    #with stdv the error of each data point from the observations.
    q_like  = Normal('q', mu=q_fit, sd=qerr_obs, observed=q_obs) 
    u_like  = Normal('u', mu=u_fit, sd=uerr_obs, observed=u_obs)  

with model:    
    #Inference
    start = find_MAP()
    step = NUTS([A,B,C,D],scaling=start)
    # draw n_post posterior samples using NUTS sampling
    n_post = 25000
    trace = sample(n_post, step, start=start)
# Out:
#  [                  0%                  ] 2 of 25000 complete in 1.6 sec
#  [                  0%                  ] 4 of 25000 complete in 2.3 sec
#  [                  0%                  ] 7 of 25000 complete in 3.1 sec
#  [                  0%                  ] 11 of 25000 complete in 3.7 sec
#  [                  0%                  ] 12 of 25000 complete in 4.4 sec
#  [                  0%                  ] 14 of 25000 complete in 5.2 sec
#  [                  0%                  ] 16 of 25000 complete in 10.7 sec
#  [                  0%                  ] 17 of 25000 complete in 12.6 sec
#  [                  0%                  ] 18 of 25000 complete in 13.7 sec
#  [                  0%                  ] 19 of 25000 complete in 14.4 sec
#  [                  0%                  ] 22 of 25000 complete in 15.8 sec
#  [                  0%                  ] 25 of 25000 complete in 16.3 sec
#  [                  0%                  ] 29 of 25000 complete in 16.8 sec
#  [                  0%                  ] 35 of 25000 complete in 20.0 sec
#  [                  0%                  ] 36 of 25000 complete in 21.4 sec
#  [                  0%                  ] 42 of 25000 complete in 22.6 sec
#  [                  0%                  ] 43 of 25000 complete in 23.2 sec
#  [                  0%                  ] 46 of 25000 complete in 23.9 sec
#  [                  0%                  ] 49 of 25000 complete in 24.5 sec
#  [                  0%                  ] 50 of 25000 complete in 25.6 sec
#  [                  0%                  ] 54 of 25000 complete in 26.1 sec
#  [                  0%                  ] 55 of 25000 complete in 26.8 sec
#  [                  0%                  ] 58 of 25000 complete in 27.5 sec
#  [                  0%                  ] 63 of 25000 complete in 28.6 sec
#  [                  0%                  ] 64 of 25000 complete in 29.3 sec
#  [                  0%                  ] 67 of 25000 complete in 30.0 sec
#  [                  0%                  ] 71 of 25000 complete in 31.1 sec
#  [                  0%                  ] 74 of 25000 complete in 31.6 sec
#  [                  0%                  ] 77 of 25000 complete in 32.4 sec
#  [                  0%                  ] 80 of 25000 complete in 33.2 sec
#  [                  0%                  ] 82 of 25000 complete in 33.7 sec
#  [                  0%                  ] 86 of 25000 complete in 34.3 sec
#  [                  0%                  ] 89 of 25000 complete in 35.0 sec
#  [                  0%                  ] 93 of 25000 complete in 35.5 sec
#  [                  0%                  ] 97 of 25000 complete in 36.1 sec
#  [                  0%                  ] 100 of 25000 complete in 37.3 sec
#  [                  0%                  ] 104 of 25000 complete in 38.1 sec
#  [                  0%                  ] 106 of 25000 complete in 39.2 sec
#  [                  0%                  ] 108 of 25000 complete in 39.9 sec
#  [                  0%                  ] 112 of 25000 complete in 40.5 sec
#  [                  0%                  ] 115 of 25000 complete in 41.0 sec
#  [                  0%                  ] 116 of 25000 complete in 41.8 sec
#  [                  0%                  ] 119 of 25000 complete in 42.4 sec
#  [                  0%                  ] 123 of 25000 complete in 43.1 sec
#  [                  0%                  ] 125 of 25000 complete in 43.7 sec
#  [                  0%                  ] 128 of 25000 complete in 44.2 sec
#  [                  0%                  ] 133 of 25000 complete in 44.8 sec
#  [                  0%                  ] 135 of 25000 complete in 45.5 sec
#  [                  0%                  ] 137 of 25000 complete in 46.1 sec
#  [                  0%                  ] 139 of 25000 complete in 47.5 sec
#  [                  0%                  ] 142 of 25000 complete in 48.3 sec
#  [                  0%                  ] 145 of 25000 complete in 49.5 sec
#  [                  0%                  ] 148 of 25000 complete in 50.0 sec
#  [                  0%                  ] 150 of 25000 complete in 50.8 sec
#  [                  0%                  ] 153 of 25000 complete in 51.4 sec
#  [                  0%                  ] 156 of 25000 complete in 52.6 sec
#  [                  0%                  ] 157 of 25000 complete in 53.2 sec
#  [                  0%                  ] 160 of 25000 complete in 53.8 sec
#  [                  0%                  ] 161 of 25000 complete in 54.4 sec
#  [                  0%                  ] 163 of 25000 complete in 55.1 sec
#  [                  0%                  ] 166 of 25000 complete in 55.6 sec
#  [                  0%                  ] 167 of 25000 complete in 56.3 sec
#  [                  0%                  ] 169 of 25000 complete in 57.3 sec
#  [                  0%                  ] 172 of 25000 complete in 58.2 sec
#  [                  0%                  ] 175 of 25000 complete in 59.8 sec
#  [                  0%                  ] 176 of 25000 complete in 60.3 sec
#  [                  0%                  ] 178 of 25000 complete in 61.1 sec
#  [                  0%                  ] 181 of 25000 complete in 62.0 sec
#  [                  0%                  ] 183 of 25000 complete in 62.6 sec
#  [                  0%                  ] 186 of 25000 complete in 63.5 sec
#  [                  0%                  ] 187 of 25000 complete in 64.2 sec
#  [                  0%                  ] 191 of 25000 complete in 64.8 sec
#  [                  0%                  ] 193 of 25000 complete in 65.3 sec
#  [                  0%                  ] 195 of 25000 complete in 65.9 sec
#  [                  0%                  ] 196 of 25000 complete in 66.7 sec
#  [                  0%                  ] 198 of 25000 complete in 67.3 sec
#  [                  0%                  ] 200 of 25000 complete in 68.2 sec
#  [                  0%                  ] 204 of 25000 complete in 68.7 sec
#  [                  0%                  ] 206 of 25000 complete in 69.3 sec
#  [                  0%                  ] 208 of 25000 complete in 69.9 sec
#  [                  0%                  ] 209 of 25000 complete in 70.6 sec
#  [                  0%                  ] 210 of 25000 complete in 71.5 sec
#  [                  0%                  ] 211 of 25000 complete in 72.0 sec
#  [                  0%                  ] 215 of 25000 complete in 73.0 sec
#  [                  0%                  ] 218 of 25000 complete in 73.7 sec
#  [                  0%                  ] 220 of 25000 complete in 74.4 sec
#  [                  0%                  ] 223 of 25000 complete in 75.1 sec
#  [                  0%                  ] 225 of 25000 complete in 75.9 sec
#  [                  0%                  ] 227 of 25000 complete in 76.7 sec
#  [                  0%                  ] 228 of 25000 complete in 77.5 sec
#  [                  0%                  ] 230 of 25000 complete in 78.5 sec
#  [                  0%                  ] 232 of 25000 complete in 79.0 sec
#  [                  0%                  ] 235 of 25000 complete in 79.8 sec
#  [                  0%                  ] 237 of 25000 complete in 80.3 sec
#  [                  0%                  ] 242 of 25000 complete in 80.8 sec
#  [                  0%                  ] 244 of 25000 complete in 81.4 sec
#  [                  0%                  ] 249 of 25000 complete in 82.0 sec
#  [                  1%                  ] 253 of 25000 complete in 82.9 sec
#  [                  1%                  ] 256 of 25000 complete in 83.7 sec
#  [                  1%                  ] 259 of 25000 complete in 84.5 sec
#  [                  1%                  ] 263 of 25000 complete in 85.4 sec
#  [                  1%                  ] 265 of 25000 complete in 85.9 sec
#  [                  1%                  ] 267 of 25000 complete in 86.6 sec
#  [                  1%                  ] 270 of 25000 complete in 87.6 sec
#  [                  1%                  ] 271 of 25000 complete in 88.4 sec
#  [                  1%                  ] 273 of 25000 complete in 89.0 sec
#  [                  1%                  ] 277 of 25000 complete in 89.8 sec
#  [                  1%                  ] 280 of 25000 complete in 90.9 sec
#  [                  1%                  ] 282 of 25000 complete in 91.5 sec
#  [                  1%                  ] 284 of 25000 complete in 92.2 sec
#  [                  1%                  ] 286 of 25000 complete in 92.7 sec
#  [                  1%                  ] 290 of 25000 complete in 93.2 sec
#  [                  1%                  ] 292 of 25000 complete in 93.7 sec
#  [                  1%                  ] 295 of 25000 complete in 94.4 sec
#  [                  1%                  ] 297 of 25000 complete in 95.1 sec
#  [                  1%                  ] 299 of 25000 complete in 95.7 sec
#  [                  1%                  ] 302 of 25000 complete in 96.7 sec
#  [                  1%                  ] 304 of 25000 complete in 97.5 sec
#  [                  1%                  ] 308 of 25000 complete in 98.2 sec
#  [                  1%                  ] 311 of 25000 complete in 99.0 sec
#  [                  1%                  ] 313 of 25000 complete in 99.7 sec
#  [                  1%                  ] 315 of 25000 complete in 100.4 sec
#  [                  1%                  ] 319 of 25000 complete in 101.2 sec
#  [                  1%                  ] 324 of 25000 complete in 102.2 sec
#  [                  1%                  ] 327 of 25000 complete in 103.4 sec
#  [                  1%                  ] 333 of 25000 complete in 104.0 sec
#  [                  1%                  ] 339 of 25000 complete in 104.6 sec
#  [                  1%                  ] 340 of 25000 complete in 105.3 sec
#  [                  1%                  ] 342 of 25000 complete in 105.8 sec
#  [                  1%                  ] 346 of 25000 complete in 106.4 sec
#  [                  1%                  ] 349 of 25000 complete in 107.0 sec
#  [                  1%                  ] 352 of 25000 complete in 107.7 sec
#  [                  1%                  ] 356 of 25000 complete in 108.3 sec
#  [                  1%                  ] 359 of 25000 complete in 109.2 sec
#  [                  1%                  ] 360 of 25000 complete in 109.9 sec
#  [                  1%                  ] 362 of 25000 complete in 110.8 sec
#  [                  1%                  ] 364 of 25000 complete in 111.6 sec
#  [                  1%                  ] 366 of 25000 complete in 112.2 sec
#  [                  1%                  ] 369 of 25000 complete in 113.0 sec
#  [                  1%                  ] 373 of 25000 complete in 113.6 sec
#  [                  1%                  ] 376 of 25000 complete in 114.1 sec
#  [                  1%                  ] 380 of 25000 complete in 114.8 sec
#  [                  1%                  ] 383 of 25000 complete in 115.6 sec
#  [                  1%                  ] 385 of 25000 complete in 116.2 sec
#  [                  1%                  ] 387 of 25000 complete in 116.9 sec
#  [                  1%                  ] 389 of 25000 complete in 117.5 sec
#  [                  1%                  ] 393 of 25000 complete in 118.1 sec
#  [                  1%                  ] 395 of 25000 complete in 118.9 sec
#  [                  1%                  ] 398 of 25000 complete in 119.5 sec
#  [                  1%                  ] 400 of 25000 complete in 120.2 sec
#  [                  1%                  ] 402 of 25000 complete in 120.7 sec
#  [                  1%                  ] 404 of 25000 complete in 121.7 sec
#  [                  1%                  ] 406 of 25000 complete in 122.6 sec
#  [                  1%                  ] 410 of 25000 complete in 123.1 sec
#  [                  1%                  ] 412 of 25000 complete in 123.8 sec
#  [                  1%                  ] 415 of 25000 complete in 124.3 sec
#  [                  1%                  ] 416 of 25000 complete in 125.1 sec
#  [                  1%                  ] 420 of 25000 complete in 125.9 sec
#  [                  1%                  ] 422 of 25000 complete in 126.7 sec
#  [                  1%                  ] 426 of 25000 complete in 127.3 sec
#  [                  1%                  ] 428 of 25000 complete in 127.9 sec
#  [                  1%                  ] 431 of 25000 complete in 128.7 sec
#  [                  1%                  ] 433 of 25000 complete in 129.2 sec
#  [                  1%                  ] 435 of 25000 complete in 129.7 sec
#  [                  1%                  ] 437 of 25000 complete in 130.5 sec
#  [                  1%                  ] 440 of 25000 complete in 131.2 sec
#  [                  1%                  ] 443 of 25000 complete in 132.3 sec
#  [                  1%                  ] 446 of 25000 complete in 133.0 sec
#  [                  1%                  ] 448 of 25000 complete in 133.6 sec
#  [                  1%                  ] 450 of 25000 complete in 134.4 sec
#  [                  1%                  ] 452 of 25000 complete in 135.2 sec
#  [                  1%                  ] 456 of 25000 complete in 136.4 sec
#  [                  1%                  ] 458 of 25000 complete in 137.6 sec
#  [                  1%                  ] 460 of 25000 complete in 138.2 sec
#  [                  1%                  ] 463 of 25000 complete in 138.8 sec
#  [                  1%                  ] 466 of 25000 complete in 139.5 sec
#  [                  1%                  ] 469 of 25000 complete in 140.2 sec
#  [                  1%                  ] 471 of 25000 complete in 141.1 sec
#  [                  1%                  ] 472 of 25000 complete in 141.6 sec
#  [                  1%                  ] 474 of 25000 complete in 142.5 sec
#  [                  1%                  ] 478 of 25000 complete in 143.3 sec
#  [                  1%                  ] 481 of 25000 complete in 144.6 sec
#  [                  1%                  ] 484 of 25000 complete in 145.2 sec
#  [                  1%                  ] 487 of 25000 complete in 145.9 sec
#  [                  1%                  ] 490 of 25000 complete in 146.7 sec
#  [                  1%                  ] 492 of 25000 complete in 147.2 sec
#  [                  1%                  ] 496 of 25000 complete in 148.3 sec
#  [                  1%                  ] 498 of 25000 complete in 149.0 sec
#  [                  2%                  ] 500 of 25000 complete in 149.5 sec
#  [                  2%                  ] 502 of 25000 complete in 150.1 sec
#  [                  2%                  ] 505 of 25000 complete in 151.3 sec
#  [                  2%                  ] 507 of 25000 complete in 152.5 sec
#  [                  2%                  ] 509 of 25000 complete in 153.3 sec
#  [                  2%                  ] 510 of 25000 complete in 154.0 sec
#  [                  2%                  ] 513 of 25000 complete in 154.8 sec
#  [                  2%                  ] 515 of 25000 complete in 155.5 sec
#  [                  2%                  ] 518 of 25000 complete in 156.0 sec
#  [                  2%                  ] 519 of 25000 complete in 156.7 sec
#  [                  2%                  ] 521 of 25000 complete in 157.2 sec
#  [                  2%                  ] 523 of 25000 complete in 158.1 sec
#  [                  2%                  ] 526 of 25000 complete in 159.0 sec
#  [                  2%                  ] 530 of 25000 complete in 159.8 sec
#  [                  2%                  ] 531 of 25000 complete in 160.4 sec
#  [                  2%                  ] 535 of 25000 complete in 160.9 sec
#  [                  2%                  ] 539 of 25000 complete in 161.9 sec
#  [                  2%                  ] 541 of 25000 complete in 162.7 sec
#  [                  2%                  ] 542 of 25000 complete in 163.5 sec
#  [                  2%                  ] 543 of 25000 complete in 164.2 sec
#  [                  2%                  ] 546 of 25000 complete in 165.0 sec
#  [                  2%                  ] 550 of 25000 complete in 165.8 sec
#  [                  2%                  ] 553 of 25000 complete in 166.9 sec
#  [                  2%                  ] 555 of 25000 complete in 167.4 sec
#  [                  2%                  ] 560 of 25000 complete in 168.0 sec
#  [                  2%                  ] 562 of 25000 complete in 168.5 sec
#  [                  2%                  ] 567 of 25000 complete in 169.6 sec
#  [                  2%                  ] 569 of 25000 complete in 170.3 sec
#  [                  2%                  ] 572 of 25000 complete in 171.1 sec
#  [                  2%                  ] 576 of 25000 complete in 171.6 sec
#  [                  2%                  ] 577 of 25000 complete in 172.1 sec
#  [                  2%                  ] 579 of 25000 complete in 172.8 sec
#  [                  2%                  ] 582 of 25000 complete in 173.6 sec
#  [                  2%                  ] 584 of 25000 complete in 174.2 sec
#  [                  2%                  ] 588 of 25000 complete in 175.0 sec
#  [                  2%                  ] 590 of 25000 complete in 175.7 sec
#  [                  2%                  ] 591 of 25000 complete in 176.4 sec
#  [                  2%                  ] 595 of 25000 complete in 176.9 sec
#  [                  2%                  ] 601 of 25000 complete in 178.1 sec
#  [                  2%                  ] 605 of 25000 complete in 179.2 sec
#  [                  2%                  ] 609 of 25000 complete in 180.5 sec
#  [                  2%                  ] 611 of 25000 complete in 181.6 sec
#  [                  2%                  ] 615 of 25000 complete in 182.3 sec
#  [                  2%                  ] 618 of 25000 complete in 182.8 sec
#  [                  2%                  ] 622 of 25000 complete in 183.4 sec
#  [                  2%                  ] 624 of 25000 complete in 184.1 sec
#  [                  2%                  ] 626 of 25000 complete in 184.7 sec
#  [                  2%                  ] 629 of 25000 complete in 185.2 sec
#  [                  2%                  ] 634 of 25000 complete in 185.8 sec
#  [                  2%                  ] 636 of 25000 complete in 186.5 sec
#  [                  2%                  ] 639 of 25000 complete in 187.2 sec
#  [                  2%                  ] 641 of 25000 complete in 188.0 sec
#  [                  2%                  ] 646 of 25000 complete in 189.2 sec
#  [                  2%                  ] 648 of 25000 complete in 190.1 sec
#  [                  2%                  ] 651 of 25000 complete in 190.8 sec
#  [                  2%                  ] 655 of 25000 complete in 191.6 sec
#  [-                 2%                  ] 658 of 25000 complete in 192.2 sec
#  [-                 2%                  ] 660 of 25000 complete in 192.8 sec
#  [-                 2%                  ] 662 of 25000 complete in 193.5 sec
#  [-                 2%                  ] 663 of 25000 complete in 194.2 sec
#  [-                 2%                  ] 670 of 25000 complete in 194.7 sec
#  [-                 2%                  ] 671 of 25000 complete in 195.4 sec
#  [-                 2%                  ] 673 of 25000 complete in 196.5 sec
#  [-                 2%                  ] 678 of 25000 complete in 197.2 sec
#  [-                 2%                  ] 682 of 25000 complete in 197.8 sec
#  [-                 2%                  ] 684 of 25000 complete in 198.8 sec
#  [-                 2%                  ] 688 of 25000 complete in 199.7 sec
#  [-                 2%                  ] 690 of 25000 complete in 200.3 sec
#  [-                 2%                  ] 693 of 25000 complete in 201.1 sec
#  [-                 2%                  ] 694 of 25000 complete in 201.8 sec
#  [-                 2%                  ] 695 of 25000 complete in 202.5 sec
#  [-                 2%                  ] 697 of 25000 complete in 203.1 sec
#  [-                 2%                  ] 700 of 25000 complete in 203.7 sec
#  [-                 2%                  ] 704 of 25000 complete in 204.8 sec
#  [-                 2%                  ] 706 of 25000 complete in 205.8 sec
#  [-                 2%                  ] 708 of 25000 complete in 206.7 sec
#  [-                 2%                  ] 713 of 25000 complete in 207.4 sec
#  [-                 2%                  ] 714 of 25000 complete in 208.1 sec
#  [-                 2%                  ] 715 of 25000 complete in 208.8 sec
#  [-                 2%                  ] 718 of 25000 complete in 209.6 sec
#  [-                 2%                  ] 721 of 25000 complete in 210.4 sec
#  [-                 2%                  ] 725 of 25000 complete in 211.2 sec
#  [-                 2%                  ] 729 of 25000 complete in 211.7 sec
#  [-                 2%                  ] 733 of 25000 complete in 212.3 sec
#  [-                 2%                  ] 737 of 25000 complete in 212.9 sec
#  [-                 2%                  ] 740 of 25000 complete in 213.5 sec
#  [-                 2%                  ] 742 of 25000 complete in 214.2 sec
#  [-                 2%                  ] 746 of 25000 complete in 215.0 sec
#  [-                 3%                  ] 750 of 25000 complete in 215.8 sec
#  [-                 3%                  ] 753 of 25000 complete in 216.7 sec
#  [-                 3%                  ] 756 of 25000 complete in 217.3 sec
#  [-                 3%                  ] 760 of 25000 complete in 217.9 sec
#  [-                 3%                  ] 763 of 25000 complete in 218.5 sec
#  [-                 3%                  ] 766 of 25000 complete in 219.0 sec
#  [-                 3%                  ] 771 of 25000 complete in 219.6 sec
#  [-                 3%                  ] 774 of 25000 complete in 220.3 sec
#  [-                 3%                  ] 775 of 25000 complete in 221.0 sec
#  [-                 3%                  ] 778 of 25000 complete in 221.7 sec
#  [-                 3%                  ] 782 of 25000 complete in 222.3 sec
#  [-                 3%                  ] 784 of 25000 complete in 222.9 sec
#  [-                 3%                  ] 787 of 25000 complete in 223.4 sec
#  [-                 3%                  ] 790 of 25000 complete in 224.1 sec
#  [-                 3%                  ] 795 of 25000 complete in 225.2 sec
#  [-                 3%                  ] 799 of 25000 complete in 225.9 sec
#  [-                 3%                  ] 803 of 25000 complete in 226.4 sec
#  [-                 3%                  ] 809 of 25000 complete in 226.9 sec
#  [-                 3%                  ] 814 of 25000 complete in 227.5 sec
#  [-                 3%                  ] 818 of 25000 complete in 228.1 sec
#  [-                 3%                  ] 820 of 25000 complete in 228.8 sec
#  [-                 3%                  ] 824 of 25000 complete in 229.6 sec
#  [-                 3%                  ] 828 of 25000 complete in 230.7 sec
#  [-                 3%                  ] 831 of 25000 complete in 231.3 sec
#  [-                 3%                  ] 833 of 25000 complete in 231.8 sec
#  [-                 3%                  ] 837 of 25000 complete in 232.5 sec
#  [-                 3%                  ] 839 of 25000 complete in 233.2 sec
#  [-                 3%                  ] 843 of 25000 complete in 233.9 sec
#  [-                 3%                  ] 847 of 25000 complete in 234.5 sec
#  [-                 3%                  ] 853 of 25000 complete in 235.3 sec
#  [-                 3%                  ] 858 of 25000 complete in 236.2 sec
#  [-                 3%                  ] 860 of 25000 complete in 236.7 sec
#  [-                 3%                  ] 864 of 25000 complete in 237.2 sec
#  [-                 3%                  ] 866 of 25000 complete in 237.8 sec
#  [-                 3%                  ] 868 of 25000 complete in 238.5 sec
#  [-                 3%                  ] 872 of 25000 complete in 239.1 sec
#  [-                 3%                  ] 875 of 25000 complete in 239.7 sec
#  [-                 3%                  ] 877 of 25000 complete in 240.4 sec
#  [-                 3%                  ] 881 of 25000 complete in 241.4 sec
#  [-                 3%                  ] 883 of 25000 complete in 241.9 sec
#  [-                 3%                  ] 884 of 25000 complete in 242.6 sec
#  [-                 3%                  ] 886 of 25000 complete in 243.4 sec
#  [-                 3%                  ] 888 of 25000 complete in 244.0 sec
#  [-                 3%                  ] 890 of 25000 complete in 244.7 sec
#  [-                 3%                  ] 893 of 25000 complete in 245.7 sec
#  [-                 3%                  ] 895 of 25000 complete in 246.3 sec
#  [-                 3%                  ] 899 of 25000 complete in 247.0 sec
#  [-                 3%                  ] 902 of 25000 complete in 247.7 sec
#  [-                 3%                  ] 906 of 25000 complete in 248.5 sec
#  [-                 3%                  ] 908 of 25000 complete in 249.1 sec
#  [-                 3%                  ] 911 of 25000 complete in 249.7 sec
#  [-                 3%                  ] 915 of 25000 complete in 250.6 sec
#  [-                 3%                  ] 919 of 25000 complete in 251.1 sec
#  [-                 3%                  ] 921 of 25000 complete in 251.8 sec
#  [-                 3%                  ] 924 of 25000 complete in 252.3 sec
#  [-                 3%                  ] 927 of 25000 complete in 253.2 sec
#  [-                 3%                  ] 930 of 25000 complete in 253.9 sec
#  [-                 3%                  ] 933 of 25000 complete in 255.0 sec
#  [-                 3%                  ] 934 of 25000 complete in 255.6 sec
#  [-                 3%                  ] 936 of 25000 complete in 256.5 sec
#  [-                 3%                  ] 937 of 25000 complete in 257.2 sec
#  [-                 3%                  ] 938 of 25000 complete in 257.7 sec
#  [-                 3%                  ] 940 of 25000 complete in 258.3 sec
#  [-                 3%                  ] 941 of 25000 complete in 259.0 sec
#  [-                 3%                  ] 943 of 25000 complete in 259.7 sec
#  [-                 3%                  ] 945 of 25000 complete in 260.2 sec
#  [-                 3%                  ] 949 of 25000 complete in 260.9 sec
#  [-                 3%                  ] 951 of 25000 complete in 261.4 sec
#  [-                 3%                  ] 956 of 25000 complete in 262.6 sec
#  [-                 3%                  ] 958 of 25000 complete in 263.4 sec
#  [-                 3%                  ] 960 of 25000 complete in 264.1 sec
#  [-                 3%                  ] 962 of 25000 complete in 264.8 sec
#  [-                 3%                  ] 966 of 25000 complete in 265.5 sec
#  [-                 3%                  ] 968 of 25000 complete in 266.3 sec
#  [-                 3%                  ] 974 of 25000 complete in 266.8 sec
#  [-                 3%                  ] 979 of 25000 complete in 267.6 sec
#  [-                 3%                  ] 983 of 25000 complete in 268.3 sec
#  [-                 3%                  ] 986 of 25000 complete in 268.9 sec
#  [-                 3%                  ] 988 of 25000 complete in 269.5 sec
#  [-                 3%                  ] 990 of 25000 complete in 270.6 sec
#  [-                 3%                  ] 992 of 25000 complete in 271.4 sec
#  [-                 3%                  ] 995 of 25000 complete in 272.1 sec
#  [-                 3%                  ] 998 of 25000 complete in 272.8 sec
#  [-                 4%                  ] 1000 of 25000 complete in 273.3 sec
#  [-                 4%                  ] 1001 of 25000 complete in 273.9 sec
#  [-                 4%                  ] 1005 of 25000 complete in 274.5 sec
#  [-                 4%                  ] 1007 of 25000 complete in 275.1 sec
#  [-                 4%                  ] 1011 of 25000 complete in 275.7 sec
#  [-                 4%                  ] 1016 of 25000 complete in 276.7 sec
#  [-                 4%                  ] 1019 of 25000 complete in 277.3 sec
#  [-                 4%                  ] 1021 of 25000 complete in 278.0 sec
#  [-                 4%                  ] 1023 of 25000 complete in 279.2 sec
#  [-                 4%                  ] 1027 of 25000 complete in 279.7 sec
#  [-                 4%                  ] 1031 of 25000 complete in 280.4 sec
#  [-                 4%                  ] 1032 of 25000 complete in 281.1 sec
#  [-                 4%                  ] 1035 of 25000 complete in 281.8 sec
#  [-                 4%                  ] 1036 of 25000 complete in 282.5 sec
#  [-                 4%                  ] 1038 of 25000 complete in 283.2 sec
#  [-                 4%                  ] 1040 of 25000 complete in 283.9 sec
#  [-                 4%                  ] 1043 of 25000 complete in 284.7 sec
#  [-                 4%                  ] 1045 of 25000 complete in 285.3 sec
#  [-                 4%                  ] 1049 of 25000 complete in 286.4 sec
#  [-                 4%                  ] 1055 of 25000 complete in 287.2 sec
#  [-                 4%                  ] 1059 of 25000 complete in 287.7 sec
#  [-                 4%                  ] 1062 of 25000 complete in 288.4 sec
#  [-                 4%                  ] 1063 of 25000 complete in 289.1 sec
#  [-                 4%                  ] 1067 of 25000 complete in 289.9 sec
#  [-                 4%                  ] 1072 of 25000 complete in 290.6 sec
#  [-                 4%                  ] 1074 of 25000 complete in 291.3 sec
#  [-                 4%                  ] 1078 of 25000 complete in 292.1 sec
#  [-                 4%                  ] 1080 of 25000 complete in 292.8 sec
#  [-                 4%                  ] 1083 of 25000 complete in 293.6 sec
#  [-                 4%                  ] 1085 of 25000 complete in 294.1 sec
#  [-                 4%                  ] 1091 of 25000 complete in 294.7 sec
#  [-                 4%                  ] 1094 of 25000 complete in 295.5 sec
#  [-                 4%                  ] 1100 of 25000 complete in 296.7 sec
#  [-                 4%                  ] 1101 of 25000 complete in 297.4 sec
#  [-                 4%                  ] 1102 of 25000 complete in 298.1 sec
#  [-                 4%                  ] 1104 of 25000 complete in 298.7 sec
#  [-                 4%                  ] 1107 of 25000 complete in 299.5 sec
#  [-                 4%                  ] 1110 of 25000 complete in 300.6 sec
#  [-                 4%                  ] 1114 of 25000 complete in 301.2 sec
#  [-                 4%                  ] 1117 of 25000 complete in 302.0 sec
#  [-                 4%                  ] 1119 of 25000 complete in 302.7 sec
#  [-                 4%                  ] 1121 of 25000 complete in 303.7 sec
#  [-                 4%                  ] 1123 of 25000 complete in 304.5 sec
#  [-                 4%                  ] 1126 of 25000 complete in 305.2 sec
#  [-                 4%                  ] 1128 of 25000 complete in 306.2 sec
#  [-                 4%                  ] 1132 of 25000 complete in 306.8 sec
#  [-                 4%                  ] 1136 of 25000 complete in 307.6 sec
#  [-                 4%                  ] 1141 of 25000 complete in 308.3 sec
#  [-                 4%                  ] 1143 of 25000 complete in 308.9 sec
#  [-                 4%                  ] 1145 of 25000 complete in 309.4 sec
#  [-                 4%                  ] 1149 of 25000 complete in 310.2 sec
#  [-                 4%                  ] 1151 of 25000 complete in 311.0 sec
#  [-                 4%                  ] 1155 of 25000 complete in 311.9 sec
#  [-                 4%                  ] 1158 of 25000 complete in 313.1 sec
#  [-                 4%                  ] 1163 of 25000 complete in 314.0 sec
#  [-                 4%                  ] 1166 of 25000 complete in 314.8 sec
#  [-                 4%                  ] 1169 of 25000 complete in 315.3 sec
#  [-                 4%                  ] 1172 of 25000 complete in 315.9 sec
#  [-                 4%                  ] 1175 of 25000 complete in 316.8 sec
#  [-                 4%                  ] 1178 of 25000 complete in 317.4 sec
#  [-                 4%                  ] 1181 of 25000 complete in 318.3 sec
#  [-                 4%                  ] 1185 of 25000 complete in 318.9 sec
#  [-                 4%                  ] 1189 of 25000 complete in 319.4 sec
#  [-                 4%                  ] 1191 of 25000 complete in 320.1 sec
#  [-                 4%                  ] 1192 of 25000 complete in 320.8 sec
#  [-                 4%                  ] 1193 of 25000 complete in 321.5 sec
#  [-                 4%                  ] 1194 of 25000 complete in 322.2 sec
#  [-                 4%                  ] 1196 of 25000 complete in 322.9 sec
#  [-                 4%                  ] 1197 of 25000 complete in 323.6 sec
#  [-                 4%                  ] 1199 of 25000 complete in 324.7 sec
#  [-                 4%                  ] 1200 of 25000 complete in 325.4 sec
#  [-                 4%                  ] 1202 of 25000 complete in 326.2 sec
#  [-                 4%                  ] 1203 of 25000 complete in 326.9 sec
#  [-                 4%                  ] 1205 of 25000 complete in 327.4 sec
#  [-                 4%                  ] 1206 of 25000 complete in 328.2 sec
#  [-                 4%                  ] 1211 of 25000 complete in 329.4 sec
#  [-                 4%                  ] 1212 of 25000 complete in 330.1 sec
#  [-                 4%                  ] 1217 of 25000 complete in 330.9 sec
#  [-                 4%                  ] 1218 of 25000 complete in 331.7 sec
#  [-                 4%                  ] 1222 of 25000 complete in 332.2 sec
#  [-                 4%                  ] 1224 of 25000 complete in 332.9 sec
#  [-                 4%                  ] 1226 of 25000 complete in 333.6 sec
#  [-                 4%                  ] 1229 of 25000 complete in 334.4 sec
#  [-                 4%                  ] 1230 of 25000 complete in 335.1 sec
#  [-                 4%                  ] 1233 of 25000 complete in 335.8 sec
#  [-                 4%                  ] 1237 of 25000 complete in 336.4 sec
#  [-                 4%                  ] 1239 of 25000 complete in 337.1 sec
#  [-                 4%                  ] 1242 of 25000 complete in 338.2 sec
#  [-                 4%                  ] 1246 of 25000 complete in 339.1 sec
#  [-                 5%                  ] 1250 of 25000 complete in 339.6 sec
#  [-                 5%                  ] 1254 of 25000 complete in 340.3 sec
#  [-                 5%                  ] 1256 of 25000 complete in 341.1 sec
#  [-                 5%                  ] 1258 of 25000 complete in 341.7 sec
#  [-                 5%                  ] 1261 of 25000 complete in 342.5 sec
#  [-                 5%                  ] 1265 of 25000 complete in 343.1 sec
#  [-                 5%                  ] 1268 of 25000 complete in 344.0 sec
#  [-                 5%                  ] 1270 of 25000 complete in 344.8 sec
#  [-                 5%                  ] 1272 of 25000 complete in 345.3 sec
#  [-                 5%                  ] 1275 of 25000 complete in 345.8 sec
#  [-                 5%                  ] 1278 of 25000 complete in 346.6 sec
#  [-                 5%                  ] 1280 of 25000 complete in 347.2 sec
#  [-                 5%                  ] 1283 of 25000 complete in 347.9 sec
#  [-                 5%                  ] 1285 of 25000 complete in 348.5 sec
#  [-                 5%                  ] 1288 of 25000 complete in 349.2 sec
#  [-                 5%                  ] 1292 of 25000 complete in 350.0 sec
#  [-                 5%                  ] 1295 of 25000 complete in 350.7 sec
#  [-                 5%                  ] 1298 of 25000 complete in 351.3 sec
#  [-                 5%                  ] 1299 of 25000 complete in 352.0 sec
#  [-                 5%                  ] 1302 of 25000 complete in 352.6 sec
#  [-                 5%                  ] 1304 of 25000 complete in 353.2 sec
#  [-                 5%                  ] 1306 of 25000 complete in 353.9 sec
#  [-                 5%                  ] 1308 of 25000 complete in 354.7 sec
#  [-                 5%                  ] 1311 of 25000 complete in 355.5 sec
#  [-                 5%                  ] 1315 of 25000 complete in 356.3 sec
#  [--                5%                  ] 1317 of 25000 complete in 357.0 sec
#  [--                5%                  ] 1322 of 25000 complete in 357.6 sec
#  [--                5%                  ] 1325 of 25000 complete in 358.1 sec
#  [--                5%                  ] 1328 of 25000 complete in 358.7 sec
#  [--                5%                  ] 1331 of 25000 complete in 359.4 sec
#  [--                5%                  ] 1334 of 25000 complete in 360.1 sec
#  [--                5%                  ] 1338 of 25000 complete in 360.7 sec
#  [--                5%                  ] 1343 of 25000 complete in 361.2 sec
#  [--                5%                  ] 1345 of 25000 complete in 361.7 sec
#  [--                5%                  ] 1350 of 25000 complete in 362.4 sec
#  [--                5%                  ] 1354 of 25000 complete in 363.2 sec
#  [--                5%                  ] 1358 of 25000 complete in 363.8 sec
#  [--                5%                  ] 1360 of 25000 complete in 364.5 sec
#  [--                5%                  ] 1362 of 25000 complete in 365.1 sec
#  [--                5%                  ] 1365 of 25000 complete in 365.7 sec
#  [--                5%                  ] 1368 of 25000 complete in 366.4 sec
#  [--                5%                  ] 1370 of 25000 complete in 367.0 sec
#  [--                5%                  ] 1372 of 25000 complete in 367.7 sec
#  [--                5%                  ] 1374 of 25000 complete in 368.4 sec
#  [--                5%                  ] 1376 of 25000 complete in 369.0 sec
#  [--                5%                  ] 1378 of 25000 complete in 369.7 sec
#  [--                5%                  ] 1380 of 25000 complete in 370.4 sec
#  [--                5%                  ] 1383 of 25000 complete in 370.9 sec
#  [--                5%                  ] 1386 of 25000 complete in 371.6 sec
#  [--                5%                  ] 1389 of 25000 complete in 372.3 sec
#  [--                5%                  ] 1391 of 25000 complete in 373.0 sec
#  [--                5%                  ] 1395 of 25000 complete in 373.8 sec
#  [--                5%                  ] 1398 of 25000 complete in 374.5 sec
#  [--                5%                  ] 1401 of 25000 complete in 375.1 sec
#  [--                5%                  ] 1404 of 25000 complete in 375.8 sec
#  [--                5%                  ] 1407 of 25000 complete in 376.7 sec
#  [--                5%                  ] 1410 of 25000 complete in 377.5 sec
#  [--                5%                  ] 1413 of 25000 complete in 378.1 sec
#  [--                5%                  ] 1415 of 25000 complete in 378.7 sec
#  [--                5%                  ] 1418 of 25000 complete in 379.6 sec
#  [--                5%                  ] 1421 of 25000 complete in 380.2 sec
#  [--                5%                  ] 1424 of 25000 complete in 381.0 sec
#  [--                5%                  ] 1428 of 25000 complete in 381.9 sec
#  [--                5%                  ] 1432 of 25000 complete in 382.5 sec
#  [--                5%                  ] 1433 of 25000 complete in 383.2 sec
#  [--                5%                  ] 1436 of 25000 complete in 383.9 sec
#  [--                5%                  ] 1440 of 25000 complete in 384.7 sec
#  [--                5%                  ] 1444 of 25000 complete in 385.5 sec
#  [--                5%                  ] 1446 of 25000 complete in 386.2 sec
#  [--                5%                  ] 1449 of 25000 complete in 386.7 sec
#  [--                5%                  ] 1453 of 25000 complete in 387.4 sec
#  [--                5%                  ] 1457 of 25000 complete in 388.5 sec
#  [--                5%                  ] 1461 of 25000 complete in 389.3 sec
#  [--                5%                  ] 1464 of 25000 complete in 389.9 sec
#  [--                5%                  ] 1466 of 25000 complete in 390.5 sec
#  [--                5%                  ] 1468 of 25000 complete in 391.0 sec
#  [--                5%                  ] 1470 of 25000 complete in 391.7 sec
#  [--                5%                  ] 1472 of 25000 complete in 392.3 sec
#  [--                5%                  ] 1475 of 25000 complete in 392.8 sec
#  [--                5%                  ] 1478 of 25000 complete in 393.5 sec
#  [--                5%                  ] 1481 of 25000 complete in 394.0 sec
#  [--                5%                  ] 1485 of 25000 complete in 395.2 sec
#  [--                5%                  ] 1487 of 25000 complete in 396.0 sec
#  [--                5%                  ] 1489 of 25000 complete in 396.5 sec
#  [--                5%                  ] 1492 of 25000 complete in 397.0 sec
#  [--                5%                  ] 1494 of 25000 complete in 397.5 sec
#  [--                5%                  ] 1497 of 25000 complete in 398.2 sec
#  [--                5%                  ] 1499 of 25000 complete in 398.7 sec
#  [--                6%                  ] 1504 of 25000 complete in 399.5 sec
#  [--                6%                  ] 1507 of 25000 complete in 400.3 sec
#  [--                6%                  ] 1509 of 25000 complete in 401.0 sec
#  [--                6%                  ] 1513 of 25000 complete in 401.6 sec
#  [--                6%                  ] 1517 of 25000 complete in 402.1 sec
#  [--                6%                  ] 1521 of 25000 complete in 402.8 sec
#  [--                6%                  ] 1525 of 25000 complete in 403.7 sec
#  [--                6%                  ] 1528 of 25000 complete in 404.2 sec
#  [--                6%                  ] 1531 of 25000 complete in 405.0 sec
#  [--                6%                  ] 1534 of 25000 complete in 405.6 sec
#  [--                6%                  ] 1536 of 25000 complete in 406.3 sec
#  [--                6%                  ] 1542 of 25000 complete in 407.0 sec
#  [--                6%                  ] 1545 of 25000 complete in 408.0 sec
#  [--                6%                  ] 1547 of 25000 complete in 408.6 sec
#  [--                6%                  ] 1551 of 25000 complete in 409.5 sec
#  [--                6%                  ] 1554 of 25000 complete in 410.6 sec
#  [--                6%                  ] 1557 of 25000 complete in 411.4 sec
#  [--                6%                  ] 1559 of 25000 complete in 412.2 sec
#  [--                6%                  ] 1563 of 25000 complete in 412.7 sec
#  [--                6%                  ] 1566 of 25000 complete in 413.6 sec
#  [--                6%                  ] 1568 of 25000 complete in 414.7 sec
#  [--                6%                  ] 1571 of 25000 complete in 415.5 sec
#  [--                6%                  ] 1573 of 25000 complete in 416.0 sec
#  [--                6%                  ] 1576 of 25000 complete in 416.6 sec
#  [--                6%                  ] 1579 of 25000 complete in 417.6 sec
#  [--                6%                  ] 1580 of 25000 complete in 418.3 sec
#  [--                6%                  ] 1586 of 25000 complete in 419.4 sec
#  [--                6%                  ] 1589 of 25000 complete in 419.9 sec
#  [--                6%                  ] 1592 of 25000 complete in 420.7 sec
#  [--                6%                  ] 1594 of 25000 complete in 421.5 sec
#  [--                6%                  ] 1596 of 25000 complete in 422.2 sec
#  [--                6%                  ] 1598 of 25000 complete in 422.7 sec
#  [--                6%                  ] 1602 of 25000 complete in 423.5 sec
#  [--                6%                  ] 1605 of 25000 complete in 424.4 sec
#  [--                6%                  ] 1607 of 25000 complete in 424.9 sec
#  [--                6%                  ] 1609 of 25000 complete in 425.9 sec
#  [--                6%                  ] 1614 of 25000 complete in 426.7 sec
#  [--                6%                  ] 1618 of 25000 complete in 427.4 sec
#  [--                6%                  ] 1621 of 25000 complete in 428.2 sec
#  [--                6%                  ] 1624 of 25000 complete in 428.7 sec
#  [--                6%                  ] 1626 of 25000 complete in 429.3 sec
#  [--                6%                  ] 1631 of 25000 complete in 429.9 sec
#  [--                6%                  ] 1633 of 25000 complete in 430.6 sec
#  [--                6%                  ] 1636 of 25000 complete in 431.7 sec
#  [--                6%                  ] 1638 of 25000 complete in 432.3 sec
#  [--                6%                  ] 1641 of 25000 complete in 432.8 sec
#  [--                6%                  ] 1645 of 25000 complete in 433.7 sec
#  [--                6%                  ] 1647 of 25000 complete in 434.3 sec
#  [--                6%                  ] 1650 of 25000 complete in 435.3 sec
#  [--                6%                  ] 1653 of 25000 complete in 436.0 sec
#  [--                6%                  ] 1656 of 25000 complete in 436.8 sec
#  [--                6%                  ] 1658 of 25000 complete in 437.5 sec
#  [--                6%                  ] 1661 of 25000 complete in 438.1 sec
#  [--                6%                  ] 1663 of 25000 complete in 438.6 sec
#  [--                6%                  ] 1666 of 25000 complete in 439.1 sec
#  [--                6%                  ] 1670 of 25000 complete in 439.7 sec
#  [--                6%                  ] 1673 of 25000 complete in 440.4 sec
#  [--                6%                  ] 1676 of 25000 complete in 441.2 sec
#  [--                6%                  ] 1678 of 25000 complete in 441.7 sec
#  [--                6%                  ] 1681 of 25000 complete in 442.3 sec
#  [--                6%                  ] 1684 of 25000 complete in 443.0 sec
#  [--                6%                  ] 1689 of 25000 complete in 443.5 sec
#  [--                6%                  ] 1692 of 25000 complete in 444.6 sec
#  [--                6%                  ] 1695 of 25000 complete in 445.4 sec
#  [--                6%                  ] 1698 of 25000 complete in 446.0 sec
#  [--                6%                  ] 1702 of 25000 complete in 447.2 sec
#  [--                6%                  ] 1705 of 25000 complete in 447.9 sec
#  [--                6%                  ] 1707 of 25000 complete in 448.5 sec
#  [--                6%                  ] 1710 of 25000 complete in 449.1 sec
#  [--                6%                  ] 1714 of 25000 complete in 449.6 sec
#  [--                6%                  ] 1718 of 25000 complete in 450.3 sec
#  [--                6%                  ] 1721 of 25000 complete in 451.1 sec
#  [--                6%                  ] 1723 of 25000 complete in 451.7 sec
#  [--                6%                  ] 1727 of 25000 complete in 452.4 sec
#  [--                6%                  ] 1728 of 25000 complete in 453.2 sec
#  [--                6%                  ] 1733 of 25000 complete in 453.7 sec
#  [--                6%                  ] 1736 of 25000 complete in 454.3 sec
#  [--                6%                  ] 1740 of 25000 complete in 455.0 sec
#  [--                6%                  ] 1743 of 25000 complete in 455.6 sec
#  [--                6%                  ] 1746 of 25000 complete in 456.4 sec
#  [--                7%                  ] 1750 of 25000 complete in 457.1 sec
#  [--                7%                  ] 1753 of 25000 complete in 457.7 sec
#  [--                7%                  ] 1755 of 25000 complete in 458.4 sec
#  [--                7%                  ] 1757 of 25000 complete in 459.2 sec
#  [--                7%                  ] 1761 of 25000 complete in 460.0 sec
#  [--                7%                  ] 1764 of 25000 complete in 460.7 sec
# ...
#  [-----------------98%----------------- ] 24614 of 25000 complete in 8631.9 sec
#  [-----------------98%----------------- ] 24615 of 25000 complete in 8632.7 sec
#  [-----------------98%----------------- ] 24617 of 25000 complete in 8636.3 sec
#  [-----------------98%----------------- ] 24619 of 25000 complete in 8637.8 sec
#  [-----------------98%----------------- ] 24620 of 25000 complete in 8638.9 sec
#  [-----------------98%----------------- ] 24621 of 25000 complete in 8639.8 sec
#  [-----------------98%----------------- ] 24622 of 25000 complete in 8640.6 sec
#  [-----------------98%----------------- ] 24623 of 25000 complete in 8641.2 sec
#  [-----------------98%----------------- ] 24625 of 25000 complete in 8641.8 sec
#  [-----------------98%----------------- ] 24626 of 25000 complete in 8642.5 sec
#  [-----------------98%----------------- ] 24628 of 25000 complete in 8644.3 sec
#  [-----------------98%----------------- ] 24630 of 25000 complete in 8644.8 sec
#  [-----------------98%----------------- ] 24631 of 25000 complete in 8645.6 sec
#  [-----------------98%----------------- ] 24633 of 25000 complete in 8646.2 sec
#  [-----------------98%----------------- ] 24636 of 25000 complete in 8648.1 sec
#  [-----------------98%----------------- ] 24637 of 25000 complete in 8649.9 sec
#  [-----------------98%----------------- ] 24638 of 25000 complete in 8650.6 sec
#  [-----------------98%----------------- ] 24639 of 25000 complete in 8652.2 sec
#  [-----------------98%----------------- ] 24640 of 25000 complete in 8655.0 sec
#  [-----------------98%----------------- ] 24641 of 25000 complete in 8656.5 sec
#  [-----------------98%----------------- ] 24642 of 25000 complete in 8657.3 sec
#  [-----------------98%----------------- ] 24643 of 25000 complete in 8658.4 sec
#  [-----------------98%----------------- ] 24645 of 25000 complete in 8661.5 sec
#  [-----------------98%----------------- ] 24647 of 25000 complete in 8662.2 sec
#  [-----------------98%----------------- ] 24650 of 25000 complete in 8663.1 sec
#  [-----------------98%----------------- ] 24652 of 25000 complete in 8664.4 sec
#  [-----------------98%----------------- ] 24653 of 25000 complete in 8666.8 sec
#  [-----------------98%----------------- ] 24654 of 25000 complete in 8667.9 sec
#  [-----------------98%----------------- ] 24657 of 25000 complete in 8668.5 sec
#  [-----------------98%----------------- ] 24661 of 25000 complete in 8669.7 sec
#  [-----------------98%----------------- ] 24663 of 25000 complete in 8670.3 sec
#  [-----------------98%----------------- ] 24664 of 25000 complete in 8671.1 sec
#  [-----------------98%----------------- ] 24666 of 25000 complete in 8672.8 sec
#  [-----------------98%----------------- ] 24669 of 25000 complete in 8673.8 sec
#  [-----------------98%----------------- ] 24670 of 25000 complete in 8675.2 sec
#  [-----------------98%----------------- ] 24673 of 25000 complete in 8676.2 sec
#  [-----------------98%----------------- ] 24674 of 25000 complete in 8676.8 sec
#  [-----------------98%----------------- ] 24677 of 25000 complete in 8677.7 sec
#  [-----------------98%----------------- ] 24678 of 25000 complete in 8678.9 sec
#  [-----------------98%----------------- ] 24679 of 25000 complete in 8679.5 sec
#  [-----------------98%----------------- ] 24681 of 25000 complete in 8680.2 sec
#  [-----------------98%----------------- ] 24683 of 25000 complete in 8681.0 sec
#  [-----------------98%----------------- ] 24685 of 25000 complete in 8681.5 sec
#  [-----------------98%----------------- ] 24688 of 25000 complete in 8683.1 sec
#  [-----------------98%----------------- ] 24690 of 25000 complete in 8683.7 sec
#  [-----------------98%----------------- ] 24692 of 25000 complete in 8684.3 sec
#  [-----------------98%----------------- ] 24695 of 25000 complete in 8685.3 sec
#  [-----------------98%----------------- ] 24697 of 25000 complete in 8686.6 sec
#  [-----------------98%----------------- ] 24700 of 25000 complete in 8687.1 sec
#  [-----------------98%----------------- ] 24703 of 25000 complete in 8688.1 sec
#  [-----------------98%----------------- ] 24705 of 25000 complete in 8689.2 sec
#  [-----------------98%----------------- ] 24706 of 25000 complete in 8690.4 sec
#  [-----------------98%----------------- ] 24707 of 25000 complete in 8691.0 sec
#  [-----------------98%----------------- ] 24708 of 25000 complete in 8691.6 sec
#  [-----------------98%----------------- ] 24711 of 25000 complete in 8692.2 sec
#  [-----------------98%----------------- ] 24713 of 25000 complete in 8692.7 sec
#  [-----------------98%----------------- ] 24716 of 25000 complete in 8693.6 sec
#  [-----------------98%----------------- ] 24717 of 25000 complete in 8694.8 sec
#  [-----------------98%----------------- ] 24718 of 25000 complete in 8695.4 sec
#  [-----------------98%----------------- ] 24721 of 25000 complete in 8696.0 sec
#  [-----------------98%----------------- ] 24723 of 25000 complete in 8696.7 sec
#  [-----------------98%----------------- ] 24726 of 25000 complete in 8697.7 sec
#  [-----------------98%----------------- ] 24729 of 25000 complete in 8699.3 sec
#  [-----------------98%----------------- ] 24730 of 25000 complete in 8699.9 sec
#  [-----------------98%----------------- ] 24731 of 25000 complete in 8700.6 sec
#  [-----------------98%----------------- ] 24733 of 25000 complete in 8701.6 sec
#  [-----------------98%----------------- ] 24734 of 25000 complete in 8703.1 sec
#  [-----------------98%----------------- ] 24735 of 25000 complete in 8703.8 sec
#  [-----------------98%----------------- ] 24736 of 25000 complete in 8705.4 sec
#  [-----------------98%----------------- ] 24738 of 25000 complete in 8706.0 sec
#  [-----------------98%----------------- ] 24739 of 25000 complete in 8707.6 sec
#  [-----------------98%----------------- ] 24740 of 25000 complete in 8708.3 sec
#  [-----------------98%----------------- ] 24741 of 25000 complete in 8709.1 sec
#  [-----------------98%----------------- ] 24744 of 25000 complete in 8710.4 sec
#  [-----------------98%----------------- ] 24746 of 25000 complete in 8711.0 sec
#  [-----------------98%----------------- ] 24749 of 25000 complete in 8712.3 sec
#  [-----------------99%----------------- ] 24750 of 25000 complete in 8713.4 sec
#  [-----------------99%----------------- ] 24752 of 25000 complete in 8714.7 sec
#  [-----------------99%----------------- ] 24753 of 25000 complete in 8715.8 sec
#  [-----------------99%----------------- ] 24756 of 25000 complete in 8717.2 sec
#  [-----------------99%----------------- ] 24757 of 25000 complete in 8718.4 sec
#  [-----------------99%----------------- ] 24758 of 25000 complete in 8719.3 sec
#  [-----------------99%----------------- ] 24759 of 25000 complete in 8719.9 sec
#  [-----------------99%----------------- ] 24761 of 25000 complete in 8721.7 sec
#  [-----------------99%----------------- ] 24763 of 25000 complete in 8722.3 sec
#  [-----------------99%----------------- ] 24764 of 25000 complete in 8723.6 sec
#  [-----------------99%----------------- ] 24765 of 25000 complete in 8724.1 sec
#  [-----------------99%----------------- ] 24767 of 25000 complete in 8725.0 sec
#  [-----------------99%----------------- ] 24768 of 25000 complete in 8725.6 sec
#  [-----------------99%----------------- ] 24769 of 25000 complete in 8726.5 sec
#  [-----------------99%----------------- ] 24771 of 25000 complete in 8727.1 sec
#  [-----------------99%----------------- ] 24774 of 25000 complete in 8728.1 sec
#  [-----------------99%----------------- ] 24777 of 25000 complete in 8729.7 sec
#  [-----------------99%----------------- ] 24778 of 25000 complete in 8731.0 sec
#  [-----------------99%----------------- ] 24780 of 25000 complete in 8731.5 sec
#  [-----------------99%----------------- ] 24782 of 25000 complete in 8732.1 sec
#  [-----------------99%----------------- ] 24784 of 25000 complete in 8732.9 sec
#  [-----------------99%----------------- ] 24785 of 25000 complete in 8734.0 sec
#  [-----------------99%----------------- ] 24786 of 25000 complete in 8734.6 sec
#  [-----------------99%----------------- ] 24788 of 25000 complete in 8735.4 sec
#  [-----------------99%----------------- ] 24790 of 25000 complete in 8736.1 sec
#  [-----------------99%----------------- ] 24793 of 25000 complete in 8736.7 sec
#  [-----------------99%----------------- ] 24796 of 25000 complete in 8737.4 sec
#  [-----------------99%----------------- ] 24798 of 25000 complete in 8738.0 sec
#  [-----------------99%----------------- ] 24800 of 25000 complete in 8738.6 sec
#  [-----------------99%----------------- ] 24801 of 25000 complete in 8739.1 sec
#  [-----------------99%----------------- ] 24802 of 25000 complete in 8740.2 sec
#  [-----------------99%----------------- ] 24804 of 25000 complete in 8740.9 sec
#  [-----------------99%----------------- ] 24806 of 25000 complete in 8741.6 sec
#  [-----------------99%----------------- ] 24808 of 25000 complete in 8742.2 sec
#  [-----------------99%----------------- ] 24810 of 25000 complete in 8743.4 sec
#  [-----------------99%----------------- ] 24813 of 25000 complete in 8744.6 sec
#  [-----------------99%----------------- ] 24814 of 25000 complete in 8745.6 sec
#  [-----------------99%----------------- ] 24815 of 25000 complete in 8746.6 sec
#  [-----------------99%----------------- ] 24817 of 25000 complete in 8747.2 sec
#  [-----------------99%----------------- ] 24820 of 25000 complete in 8747.8 sec
#  [-----------------99%----------------- ] 24822 of 25000 complete in 8748.5 sec
#  [-----------------99%----------------- ] 24824 of 25000 complete in 8749.0 sec
#  [-----------------99%----------------- ] 24826 of 25000 complete in 8749.6 sec
#  [-----------------99%----------------- ] 24829 of 25000 complete in 8750.9 sec
#  [-----------------99%----------------- ] 24832 of 25000 complete in 8751.7 sec
#  [-----------------99%----------------- ] 24836 of 25000 complete in 8752.6 sec
#  [-----------------99%----------------- ] 24838 of 25000 complete in 8753.2 sec
#  [-----------------99%----------------- ] 24840 of 25000 complete in 8754.1 sec
#  [-----------------99%----------------- ] 24842 of 25000 complete in 8754.9 sec
#  [-----------------99%----------------- ] 24844 of 25000 complete in 8755.5 sec
#  [-----------------99%----------------- ] 24846 of 25000 complete in 8756.2 sec
#  [-----------------99%----------------- ] 24848 of 25000 complete in 8756.8 sec
#  [-----------------99%----------------- ] 24850 of 25000 complete in 8757.5 sec
#  [-----------------99%----------------- ] 24853 of 25000 complete in 8758.3 sec
#  [-----------------99%----------------- ] 24855 of 25000 complete in 8758.8 sec
#  [-----------------99%----------------- ] 24858 of 25000 complete in 8759.4 sec
#  [-----------------99%----------------- ] 24860 of 25000 complete in 8760.5 sec
#  [-----------------99%----------------- ] 24861 of 25000 complete in 8761.1 sec
#  [-----------------99%----------------- ] 24864 of 25000 complete in 8761.6 sec
#  [-----------------99%----------------- ] 24866 of 25000 complete in 8762.2 sec
#  [-----------------99%----------------- ] 24869 of 25000 complete in 8762.8 sec
#  [-----------------99%----------------- ] 24871 of 25000 complete in 8764.1 sec
#  [-----------------99%----------------- ] 24873 of 25000 complete in 8764.7 sec
#  [-----------------99%----------------- ] 24876 of 25000 complete in 8765.3 sec
#  [-----------------99%----------------- ] 24879 of 25000 complete in 8765.9 sec
#  [-----------------99%----------------- ] 24881 of 25000 complete in 8766.6 sec
#  [-----------------99%----------------- ] 24883 of 25000 complete in 8767.2 sec
#  [-----------------99%----------------- ] 24886 of 25000 complete in 8768.1 sec
#  [-----------------99%----------------- ] 24887 of 25000 complete in 8769.1 sec
#  [-----------------99%----------------- ] 24889 of 25000 complete in 8769.8 sec
#  [-----------------99%----------------- ] 24891 of 25000 complete in 8770.4 sec
#  [-----------------99%----------------- ] 24894 of 25000 complete in 8771.2 sec
#  [-----------------99%----------------- ] 24897 of 25000 complete in 8771.8 sec
#  [-----------------99%----------------- ] 24900 of 25000 complete in 8772.3 sec
#  [-----------------99%----------------- ] 24902 of 25000 complete in 8773.2 sec
#  [-----------------99%----------------- ] 24904 of 25000 complete in 8773.9 sec
#  [-----------------99%----------------- ] 24905 of 25000 complete in 8774.8 sec
#  [-----------------99%----------------- ] 24908 of 25000 complete in 8775.7 sec
#  [-----------------99%----------------- ] 24911 of 25000 complete in 8776.6 sec
#  [-----------------99%----------------- ] 24913 of 25000 complete in 8777.2 sec
#  [-----------------99%----------------- ] 24915 of 25000 complete in 8777.9 sec
#  [-----------------99%----------------- ] 24919 of 25000 complete in 8778.4 sec
#  [-----------------99%----------------- ] 24920 of 25000 complete in 8779.5 sec
#  [-----------------99%----------------- ] 24921 of 25000 complete in 8780.1 sec
#  [-----------------99%----------------- ] 24924 of 25000 complete in 8780.7 sec
#  [-----------------99%----------------- ] 24926 of 25000 complete in 8781.3 sec
#  [-----------------99%----------------- ] 24927 of 25000 complete in 8781.8 sec
#  [-----------------99%----------------- ] 24928 of 25000 complete in 8782.9 sec
#  [-----------------99%----------------- ] 24930 of 25000 complete in 8783.4 sec
#  [-----------------99%----------------- ] 24932 of 25000 complete in 8784.2 sec
#  [-----------------99%----------------- ] 24933 of 25000 complete in 8784.8 sec
#  [-----------------99%----------------- ] 24935 of 25000 complete in 8785.4 sec
#  [-----------------99%----------------- ] 24937 of 25000 complete in 8786.2 sec
#  [-----------------99%----------------- ] 24938 of 25000 complete in 8786.7 sec
#  [-----------------99%----------------- ] 24940 of 25000 complete in 8788.0 sec
#  [-----------------99%----------------- ] 24941 of 25000 complete in 8788.6 sec
#  [-----------------99%----------------- ] 24942 of 25000 complete in 8789.8 sec
#  [-----------------99%----------------- ] 24943 of 25000 complete in 8790.3 sec
#  [-----------------99%----------------- ] 24944 of 25000 complete in 8790.9 sec
#  [-----------------99%----------------- ] 24946 of 25000 complete in 8791.4 sec
#  [-----------------99%----------------- ] 24948 of 25000 complete in 8792.1 sec
#  [-----------------99%----------------- ] 24951 of 25000 complete in 8793.6 sec
#  [-----------------99%----------------- ] 24954 of 25000 complete in 8794.6 sec
#  [-----------------99%----------------- ] 24955 of 25000 complete in 8795.1 sec
#  [-----------------99%----------------- ] 24957 of 25000 complete in 8795.7 sec
#  [-----------------99%----------------- ] 24961 of 25000 complete in 8796.6 sec
#  [-----------------99%----------------- ] 24965 of 25000 complete in 8797.7 sec
#  [-----------------99%----------------- ] 24967 of 25000 complete in 8798.6 sec
#  [-----------------99%----------------- ] 24972 of 25000 complete in 8799.6 sec
#  [-----------------99%----------------- ] 24973 of 25000 complete in 8800.2 sec
#  [-----------------99%----------------- ] 24976 of 25000 complete in 8800.8 sec
#  [-----------------99%----------------- ] 24978 of 25000 complete in 8801.4 sec
#  [-----------------99%----------------- ] 24979 of 25000 complete in 8802.5 sec
#  [-----------------99%----------------- ] 24981 of 25000 complete in 8803.2 sec
#  [-----------------99%----------------- ] 24984 of 25000 complete in 8803.7 sec
#  [-----------------99%----------------- ] 24987 of 25000 complete in 8804.7 sec
#  [-----------------99%----------------- ] 24988 of 25000 complete in 8805.2 sec
#  [-----------------99%----------------- ] 24989 of 25000 complete in 8805.8 sec
#  [-----------------99%----------------- ] 24990 of 25000 complete in 8806.4 sec
#  [-----------------99%----------------- ] 24992 of 25000 complete in 8807.1 sec
#  [-----------------99%----------------- ] 24994 of 25000 complete in 8807.9 sec
#  [-----------------99%----------------- ] 24995 of 25000 complete in 8808.5 sec
#  [-----------------99%----------------- ] 24999 of 25000 complete in 8809.1 sec
#  [-----------------100%-----------------] 25001 of 25000 complete in 8809.6 sec

# %%
#############
### PLOTS ###
#############
#Remove the first n_steps from the trace
n_steps = 5000
#Plots of the posteriors and trace to check convergence beyond n_step.
traceplot(trace[n_steps:],['A','B','C','D']);

# %% [markdown]
# ##### Posteriors and fitting

# %%
#Data from trace to dataframe using pandas
df_trace = trace_to_dataframe(trace[n_steps:])

################
### Best fit ###
################
A_m     = stats.mode(df_trace.A)[0]
B_m     = stats.mode(df_trace.B)[0]
C_m     = stats.mode(df_trace.C)[0]
D_m     = stats.mode(df_trace.D)[0]

A_m = trace[n_steps:].get_values('A').mean()
B_m = trace[n_steps:].get_values('B').mean()
C_m = trace[n_steps:].get_values('C').mean()
D_m = trace[n_steps:].get_values('D').mean()


fa = fa_bn*l_bn
fe = fe_bn*l_bn

qa_bestfit = A_m*fa
qe_bestfit = B_m*fe
q_bestfit = qa_bestfit + qe_bestfit

ua_bestfit = C_m*fa
ue_bestfit = D_m*fe
u_bestfit = ua_bestfit + ue_bestfit


p_bestfit  = 100.*np.sqrt(q_bestfit*q_bestfit + u_bestfit*u_bestfit)
p_a_bestfit = 100.*np.sqrt(qa_bestfit*qa_bestfit + ua_bestfit*ua_bestfit) 
p_e_bestfit = 100.*np.sqrt(qe_bestfit*qe_bestfit + ue_bestfit*ue_bestfit) 

pa_bestfit   = 0.5*np.arctan(u_bestfit/q_bestfit)*180./3.1415 
pa_a_bestfit = 0.5*np.arctan(ua_bestfit/qa_bestfit)*180./3.1415 + zeros(len(l_bn))
pa_e_bestfit = 0.5*np.arctan(ue_bestfit/qe_bestfit)*180./3.1415 + zeros(len(l_bn))


##################
### Posteriors ###
##################
#Extracting the posteriors from the interval 
cred_interval_A = df_trace['A'].quantile(.25), df_trace['A'].quantile(.75)
cred_interval_B = df_trace['B'].quantile(.25), df_trace['B'].quantile(.75)
cred_interval_C = df_trace['C'].quantile(.25), df_trace['C'].quantile(.75)
cred_interval_D = df_trace['D'].quantile(.25), df_trace['D'].quantile(.75)

A_interval = trace.A[n_steps:][np.where((trace.A[n_steps:] < max(cred_interval_A))
                                             & (trace.A[n_steps:] > min(cred_interval_A)))]

B_interval = trace.B[n_steps:][np.where((trace.B[n_steps:] < max(cred_interval_B))
                                             & (trace.B[n_steps:] > min(cred_interval_B)))]

C_interval = trace.C[n_steps:][np.where((trace.C[n_steps:] < max(cred_interval_C))
                                             & (trace.C[n_steps:] > min(cred_interval_C)))]

D_interval = trace.D[n_steps:][np.where((trace.D[n_steps:] < max(cred_interval_D))
                                             & (trace.D[n_steps:] > min(cred_interval_D)))]

###############
### Figures ###
###############
font_size=15.0
label_size=50.
lw_components = 2.
lw_trace = 1.
ll = l_bn
alpha = 0.02
fig,(ax1,ax2,ax3,ax4) = plt.subplots(1,4,figsize=(27.5,4.5),dpi=120)

for ii in range(0,len(A_interval)):
    qa = A_interval[ii] * fa 
    qe = B_interval[ii] * fe 
    q = qa + qe
    ax1.plot(ll,q,lw=lw_trace,color='red',alpha=alpha)

    ua = C_interval[ii] * fa
    ue = D_interval[ii] * fe 
    u = ua + ue
    ax2.plot(ll,u,lw=lw_trace,color='red',alpha=alpha)
    
    p = 100*np.sqrt(q*q + u*u)
    p_a = 100*np.sqrt(qa*qa + ua*ua) 
    p_e = 100*np.sqrt(qe*qe + ue*ue) 
    ax3.plot(ll,p,lw=lw_trace,color='red',alpha=alpha)
    ax3.plot(ll,p_a,lw=lw_trace,color='grey',alpha=alpha)
    ax3.plot(ll,p_e,lw=lw_trace,color='grey',alpha=alpha)
    
    pa = 0.5*np.arctan(u/q)*180./3.1592
    pa_a = 0.5*np.arctan(ua/qa)*180./3.1592
    pa_e = 0.5*np.arctan(ue/qe)*180./3.1592
    ax4.plot(ll,pa,lw=lw_trace,color='red',alpha=alpha)
    ax4.plot(ll,pa_a,lw=lw_trace,color='grey',alpha=alpha)
    ax4.plot(ll,pa_e,lw=lw_trace,color='grey',alpha=alpha)

#q
ax1.errorbar(l_obs,q_obs,yerr=qerr_obs,fmt='o',label='W51',color='blue')
ax1.plot(ll,q_bestfit,lw=lw_components,color='black',label='Model: total')
ax1.plot(ll,qa_bestfit,lw=lw_components,color='black',linestyle='-.',label='Model: absorptive component')
ax1.plot(ll,qe_bestfit,lw=lw_components,color='black',linestyle=':',label='Model: emissive component')

ax1.set_xlabel('Wavelength ($\mu$m)',fontsize=font_size)
ax1.set_ylabel('q',fontsize=font_size)
ax1.set_ylim([-0.07,0.07])
ax1.set_xlim([7,14])
ax1.xaxis.set_tick_params(labelsize=font_size)
ax1.yaxis.set_tick_params(labelsize=font_size)


#u
ax2.errorbar(l_obs,u_obs,yerr=uerr_obs,fmt='o',label='W51',color='blue')
ax2.plot(ll,u_bestfit,lw=lw_components,color='black',label='Model: total')
ax2.plot(ll,ua_bestfit,lw=lw_components,color='black',linestyle='-.',label='Model: absorptive component')
ax2.plot(ll,ue_bestfit,lw=lw_components,color='black',linestyle=':',label='Model: emissive component')


ax2.set_xlabel('Wavelength ($\mu$m)',fontsize=font_size)
ax2.set_ylabel('u',fontsize=font_size)
ax2.set_ylim([-0.07,0.07])
ax2.set_xlim([7,14])
ax2.xaxis.set_tick_params(labelsize=font_size)
ax2.yaxis.set_tick_params(labelsize=font_size)

#p
ax3.errorbar(l_obs,p_obs,yerr=perr_obs,fmt='o',label='W51',color='blue')
ax3.plot(ll,p_bestfit,lw=lw_components,color='black',label='Model: total')
ax3.plot(ll,p_a_bestfit,lw=lw_components,color='black',linestyle='-.',label='Model: absorptive component')
ax3.plot(ll,p_e_bestfit,lw=lw_components,color='black',linestyle=':',label='Model: emissive component')


ax3.set_xlabel('Wavelength ($\mu$m)',fontsize=font_size)
ax3.set_ylabel('Degree of polarization (%)',fontsize=font_size)
ax3.set_ylim([0,8])
ax3.set_xlim([7,14])
ax3.xaxis.set_tick_params(labelsize=font_size)
ax3.yaxis.set_tick_params(labelsize=font_size)

#pa
ax4.errorbar(l_obs,pa_obs,yerr=pa_err_obs,fmt='o',label='W51',color='blue')
ax4.plot(ll,pa_bestfit,lw=lw_components,color='black',label='Total Model')
ax4.plot(ll,pa_a_bestfit,lw=lw_components,color='black',linestyle='-.',label='absorptive component')
ax4.plot(ll,pa_e_bestfit,lw=lw_components,color='black',linestyle=':',label='emissive component')

ax4.set_xlabel('Wavelength ($\mu$m)',fontsize=font_size)
ax4.set_ylabel('P.A. of polarization',fontsize=font_size)
ax4.set_ylim([-90,90])
ax4.set_xlim([7,14])
ax4.xaxis.set_tick_params(labelsize=font_size)
ax4.yaxis.set_tick_params(labelsize=font_size)

ax1.legend(loc='lower left')


## Save Fig. to PDF and display
plt.savefig('W51_model.pdf')
os.system('open W51_model.pdf')
# Out:
# 0

# %%
#Measured values for analysis
#Min
qa_min = min(cred_interval_A) * fa 
qe_min = min(cred_interval_B) * fe
q_min = qa_min + qe_min
ua_min = min(cred_interval_C) * fa 
ue_min = min(cred_interval_D) * fe
u_min = ua_min + ue_min
p_min = 100*np.sqrt(q_min*q_min + u_min*u_min)
p_a_min = 100*np.sqrt(qa_min*qa_min + ua_min*ua_min) 
p_e_min = 100*np.sqrt(qe_min*qe_min + ue_min*ue_min)
pa_min = 0.5*np.arctan(u_min/q_min)*180./3.1592
pa_a_min = 0.5*np.arctan(ua_min/qa_min)*180./3.1592
pa_e_min = 0.5*np.arctan(ue_min/qe_min)*180./3.1592

#Max
qa_max = max(cred_interval_A) * fa 
qe_max = max(cred_interval_B) * fe
q_max = qa_max + qe_max
ua_max = max(cred_interval_C) * fa 
ue_max = max(cred_interval_D) * fe
u_max = ua_max + ue_max
p_max = 100*np.sqrt(q_max*q_max + u_max*u_max)
p_a_max = 100*np.sqrt(qa_max*qa_max + ua_max*ua_max) 
p_e_max = 100*np.sqrt(qe_max*qe_max + ue_max*ue_max)
pa_max = 0.5*np.arctan(u_max/q_max)*180./3.1592
pa_a_max = 0.5*np.arctan(ua_max/qa_max)*180./3.1592
pa_e_max = 0.5*np.arctan(ue_max/qe_max)*180./3.1592

# %% [markdown]
# Smith et al. (2000) found the following values from their fitting in Table 4:
# Emissive & Absorptive component:
#
#     P_a  = 6.0  +/- 0.3 %
#
#     PA_a = 136 +/- 2 degrees
#
#     P_e  = 2.8 +/- .3 %
#
#     PA_e = 36 +/- 3 degrees

# %%
#Maximum of he absorptive component
n_max = np.where(p_a_bestfit == max(p_a_bestfit))

print 'The values from the developed Bayesian approach are:'
print 'P_a =',round(max(p_a_bestfit),1),'+',round(max(p_a_bestfit)-max(p_a_max),1),'-',round(max(p_a_min)-max(p_a_bestfit),1),'%'
print 'PA_a =',round(pa_a_bestfit[0],0),'+',round(pa_a_max[0]-pa_a_bestfit[0],0),'-',round(pa_a_bestfit[0]-pa_a_min[0],0),'degrees'
print 'P_e =',round(p_e_bestfit[n_max],1),'+',round(p_e_max[n_max]-p_e_bestfit[n_max],1),'-',round(p_e_bestfit[n_max]-p_e_min[n_max],1),'%'
print 'PA_e =',round(pa_e_bestfit[0],0),'+',round(pa_e_bestfit[0]-pa_e_max[0],0),'-',round(pa_e_min[0]-pa_e_bestfit[0],0),'degrees'
# Out:
# The values from the developed Bayesian approach are:
# P_a = 7.3 + 0.6 - 0.6 %
# PA_a = -41.0 + 3.0 - 2.0 degrees
# P_e = 3.5 + 0.6 - 0.6 %
# PA_e = 43.0 + 3.0 - -85.0 degrees
