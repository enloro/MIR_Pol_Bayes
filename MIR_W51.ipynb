# %% [markdown]
# # Dichroic polarization at mid-infrared wavelengths: a Bayesian approach

# %% [markdown]
# The aim of this code is to develop a Bayesian approach to infere the absorptive and emissive componets of a given observations. In this case the observations are those of W51 IRS extracted from Smith et al. (2000, MNRAS, 312, 327), fig. 2.

# %%
# %matplotlib inline
import os
from pylab import *
from pymc3 import  *
from pymc3.stats import *
import numpy as np
import matplotlib.pyplot as plt
from readcol import readcol
import patsy
import theano
from pandas import *
from statsmodels.formula.api import glm as glm_sm
import statsmodels.api as s
import numpy as np
from scipy import stats

# %% [markdown]
# ##### Reading BN data to model the absorptive and emissive components

# %% [markdown]
# The absorptive and emissive componets were extracted from fig. 1 in Smith et al. (2000, MNRAS, 312, 327)

# %%
#At this stage of the modeling the appropiate absorptive/emissive polarization components can be introduced.
#The user can introduce their own customized dichroic compoents based on a specific dust composition,
#or if silicate-like grains are used then the user can simply use the default dichroic components
#supplied by this model.

#In the case the user want to use diferent extinction curve,
#the extinction curve of Rv=5.5 by Draine and collaborators can be used, extracted from
#ftp://ftp.astro.princeton.edu/draine/dust/mix/kext_albedo_WD_MW_5.5A_30_D03.all
#l_ext,tau_ext=readcol("ext_Rv55.dat",twod=False)

#Then the emissive and absorptive componets can be written as:
#fe_bn = fa_bn/tau_ext
#fe_bn = fe_bn/max(fe_bn)


### Observations
#BN absorptive component use for modeling from Smith et al. (2000, MNRAS, 312, 327) & Aitken+04 (MNRAS, 348, 279) 
l_bn,fa_bn=readcol("BN_fa.dat",twod=False)
l_bn,fe_bn=readcol("BN_fe.dat",twod=False)



###############
### Figures ###
###############
font_size=6.0
label_size=6.
lw = 3.
fig,(ax1) = plt.subplots(1,1,figsize=(7,4),dpi=120)

#Model
ax1.plot(l_bn,fa_bn,color='black',lw=lw,label='Absorptive component')
ax1.plot(l_bn,fe_bn,color='black',lw=lw,linestyle='-.',label='Emissive component')

ax1.set_xlabel('Wavelength ($\mu$m)')
ax1.set_ylabel('Normalized polarization')
ax1.set_ylim([0,1])
ax1.set_xlim([7,13])
ax1.legend(loc='best')

## Save Fig. to PDF and display
plt.savefig('model.pdf')
#os.system('open model.pdf')
# Out:
# Removing 1 rows that don't match most common length 2.
# 25 rows read into array.

# %% [markdown]
# ##### Reading the W51 IRS spectroscopic observations

# %% [markdown]
# Data from Aitken et al. (2000, MNRAS, 348, 279). This data is used to compare with the results from their paper.

# %%
### Observations

#W51 IRS observations
l_w51,q_w51=readcol("W51_q.dat",twod=False)
l_w51,qerr_w51=readcol("W51_qerr.dat",twod=False)
l_w51,u_w51=readcol("W51_u.dat",twod=False)
l_w51,uerr_w51=readcol("W51_uerr.dat",twod=False)

#Transform input data in 
qerr_w51 = qerr_w51 - q_w51
uerr_w51 = uerr_w51 - u_w51

q_obs = q_w51 
u_obs = u_w51
qerr_obs = qerr_w51 
uerr_obs = uerr_w51
l_obs = l_w51

p_obs   = 100.*np.sqrt(q_obs*q_obs + u_obs*u_obs)
perr_obs = 100.*np.sqrt((q_obs+qerr_obs)*(q_obs+qerr_obs) + (u_obs+uerr_obs)*(u_obs+uerr_obs)) - p_obs 

pa_obs   = 0.5*np.arctan(u_obs/q_obs)*180./3.1415 
pa_err_obs   = 0.5*np.arctan((u_obs+uerr_obs)/(q_obs+qerr_obs))*180./3.1415 - pa_obs
####



###############
### Figures ###
###############
font_size=6.0
label_size=6.
lw = 3.
fig,(ax1,ax2,ax3,ax4) = plt.subplots(1,4,figsize=(25.0,5.),dpi=120)

#q
ax1.errorbar(l_obs,q_obs,yerr=qerr_obs,fmt='o',label='q',color='blue')

ax1.set_xlabel('Wavelength ($\mu$m)')
ax1.set_ylabel('q')
ax1.set_ylim([-0.05,0.05])
ax1.set_xlim([7,14])
ax1.legend(loc='best')

#u
ax2.errorbar(l_obs,u_obs,yerr=uerr_obs,fmt='o',label='u',color='blue')

ax2.set_xlabel('Wavelength ($\mu$m)')
ax2.set_ylabel('u')
ax2.set_ylim([-0.05,0.05])
ax2.set_xlim([7,14])
ax2.legend(loc='best')

#p
ax3.errorbar(l_obs,p_obs,yerr=perr_obs,fmt='o',label='P',color='blue')

ax3.set_xlabel('Wavelength ($\mu$m)')
ax3.set_ylabel('Degree of polarization')
ax3.set_ylim([0,10])
ax3.set_xlim([7,14])
ax3.legend(loc='best')

#pa
ax4.errorbar(l_obs,pa_obs,yerr=pa_err_obs,fmt='o',label='PA',color='blue')


ax4.set_xlabel('Wavelength ($\mu$m)')
ax4.set_ylabel('P.A. of polarization')
ax4.set_ylim([-90,90])
ax4.set_xlim([7,14])
ax4.legend(loc='best')
# Out:
# Removing 1 rows that don't match most common length 2.
# 25 rows read into array.
# Removing 1 rows that don't match most common length 2.
# 25 rows read into array.
# Removing 1 rows that don't match most common length 2.
# 25 rows read into array.
# Removing 1 rows that don't match most common length 2.
# 25 rows read into array.

# %% [markdown]
# ##### Inference Model

# %%
#The aim is to infer q and u (as shown in the above plots) using the linear combination 
#of 4 independent parameters (A,B,C,D) and 2 already known empirical functions (fa, fe).
#q = A*fa*lambda + B*fe*lambda
#u = C*fa*lambda + D*fe*lambda

#Boundaries of A,B,C,D factors by n_minmax time to the min. and max. of the observables q and u.
n_minmax = 5
qmin = min(q_obs)
umin = min(u_obs)
if umin < 0: 
    u_lower = umin + n_minmax*umin
else:
    u_lower = umin - n_minmax*umin
if qmin < 0:
    q_lower = qmin + n_minmax*qmin
else:
    q_lower = qmin - n_minmax*qmin

qmax = max(q_obs)
umax = max(u_obs)
if umax < 0: 
    u_upper = umax - n_minmax*umax
else:
    u_upper = umax + n_minmax*umax
if qmax < 0:
    q_upper = qmax - n_minmax*qmax
else:
    q_upper = qmax + n_minmax*qmax
    
    
#Built the model
with Model() as model:
    #Variables are Uniform functions with width equal to 5 x std(q,u)
    A  = Uniform('A',lower=q_lower,upper=q_upper)
    B  = Uniform('B',lower=q_lower,upper=q_upper)
    C  = Uniform('C',lower=u_lower,upper=u_upper)
    D  = Uniform('D',lower=u_lower,upper=u_upper)
    #Deterministic model. Dependence of variables
    qa = A*fa_bn*l_obs
    qe = B*fe_bn*l_obs
    ua = C*fa_bn*l_obs
    ue = D*fe_bn*l_obs
    q_fit = qa + qe
    u_fit = ua + ue
    # Data likelihood. Normal distributions per each observable (data point per wavelength) 
    #with stdv the error of each data point from the observations.
    q_like  = Normal('q', mu=q_fit, sd=qerr_obs, observed=q_obs) 
    u_like  = Normal('u', mu=u_fit, sd=uerr_obs, observed=u_obs)  

with model:    
    #Inference
    start = find_MAP()
    step = NUTS([A,B,C,D],scaling=start)
    # draw n_post posterior samples using NUTS sampling
    n_post = 25000
    trace = sample(n_post, step, start=start)
# Out:
#  [                  0%                  ] 2 of 25000 complete in 0.6 sec
#  [                  0%                  ] 5 of 25000 complete in 1.5 sec
#  [                  0%                  ] 7 of 25000 complete in 2.5 sec
#  [                  0%                  ] 9 of 25000 complete in 3.5 sec
#  [                  0%                  ] 11 of 25000 complete in 4.4 sec
#  [                  0%                  ] 13 of 25000 complete in 5.3 sec
#  [                  0%                  ] 16 of 25000 complete in 6.1 sec
#  [                  0%                  ] 19 of 25000 complete in 7.9 sec
#  [                  0%                  ] 20 of 25000 complete in 8.6 sec
#  [                  0%                  ] 22 of 25000 complete in 9.2 sec
#  [                  0%                  ] 24 of 25000 complete in 9.9 sec
#  [                  0%                  ] 25 of 25000 complete in 11.5 sec
#  [                  0%                  ] 26 of 25000 complete in 13.0 sec
#  [                  0%                  ] 29 of 25000 complete in 13.6 sec
#  [                  0%                  ] 32 of 25000 complete in 14.5 sec
#  [                  0%                  ] 34 of 25000 complete in 15.1 sec
#  [                  0%                  ] 36 of 25000 complete in 16.2 sec
#  [                  0%                  ] 40 of 25000 complete in 16.8 sec
#  [                  0%                  ] 43 of 25000 complete in 17.6 sec
#  [                  0%                  ] 45 of 25000 complete in 18.2 sec
#  [                  0%                  ] 48 of 25000 complete in 19.0 sec
#  [                  0%                  ] 51 of 25000 complete in 19.8 sec
#  [                  0%                  ] 53 of 25000 complete in 21.7 sec
#  [                  0%                  ] 54 of 25000 complete in 23.3 sec
#  [                  0%                  ] 56 of 25000 complete in 24.6 sec
#  [                  0%                  ] 59 of 25000 complete in 25.2 sec
#  [                  0%                  ] 62 of 25000 complete in 25.9 sec
#  [                  0%                  ] 66 of 25000 complete in 26.7 sec
#  [                  0%                  ] 69 of 25000 complete in 27.2 sec
#  [                  0%                  ] 72 of 25000 complete in 27.8 sec
#  [                  0%                  ] 74 of 25000 complete in 28.3 sec
#  [                  0%                  ] 76 of 25000 complete in 29.9 sec
#  [                  0%                  ] 77 of 25000 complete in 30.7 sec
#  [                  0%                  ] 79 of 25000 complete in 32.0 sec
#  [                  0%                  ] 82 of 25000 complete in 33.1 sec
#  [                  0%                  ] 83 of 25000 complete in 33.9 sec
#  [                  0%                  ] 86 of 25000 complete in 34.4 sec
#  [                  0%                  ] 89 of 25000 complete in 35.1 sec
#  [                  0%                  ] 90 of 25000 complete in 35.9 sec
#  [                  0%                  ] 94 of 25000 complete in 36.5 sec
#  [                  0%                  ] 97 of 25000 complete in 37.3 sec
#  [                  0%                  ] 99 of 25000 complete in 38.0 sec
#  [                  0%                  ] 104 of 25000 complete in 38.5 sec
#  [                  0%                  ] 106 of 25000 complete in 39.4 sec
#  [                  0%                  ] 109 of 25000 complete in 40.1 sec
#  [                  0%                  ] 113 of 25000 complete in 40.8 sec
#  [                  0%                  ] 115 of 25000 complete in 41.4 sec
#  [                  0%                  ] 118 of 25000 complete in 42.6 sec
#  [                  0%                  ] 120 of 25000 complete in 43.5 sec
#  [                  0%                  ] 122 of 25000 complete in 44.2 sec
#  [                  0%                  ] 126 of 25000 complete in 44.9 sec
#  [                  0%                  ] 128 of 25000 complete in 45.4 sec
#  [                  0%                  ] 131 of 25000 complete in 46.0 sec
#  [                  0%                  ] 136 of 25000 complete in 46.8 sec
#  [                  0%                  ] 138 of 25000 complete in 47.5 sec
#  [                  0%                  ] 141 of 25000 complete in 48.3 sec
#  [                  0%                  ] 142 of 25000 complete in 49.0 sec
#  [                  0%                  ] 145 of 25000 complete in 49.8 sec
#  [                  0%                  ] 147 of 25000 complete in 50.5 sec
#  [                  0%                  ] 149 of 25000 complete in 51.2 sec
#  [                  0%                  ] 150 of 25000 complete in 51.9 sec
#  [                  0%                  ] 152 of 25000 complete in 52.5 sec
#  [                  0%                  ] 155 of 25000 complete in 53.0 sec
#  [                  0%                  ] 157 of 25000 complete in 53.7 sec
#  [                  0%                  ] 160 of 25000 complete in 54.2 sec
#  [                  0%                  ] 162 of 25000 complete in 54.8 sec
#  [                  0%                  ] 165 of 25000 complete in 55.4 sec
#  [                  0%                  ] 170 of 25000 complete in 56.4 sec
#  [                  0%                  ] 173 of 25000 complete in 56.9 sec
#  [                  0%                  ] 176 of 25000 complete in 58.2 sec
#  [                  0%                  ] 178 of 25000 complete in 58.8 sec
#  [                  0%                  ] 182 of 25000 complete in 59.6 sec
#  [                  0%                  ] 183 of 25000 complete in 60.4 sec
#  [                  0%                  ] 184 of 25000 complete in 61.1 sec
#  [                  0%                  ] 188 of 25000 complete in 61.8 sec
#  [                  0%                  ] 189 of 25000 complete in 62.4 sec
#  [                  0%                  ] 190 of 25000 complete in 63.1 sec
#  [                  0%                  ] 192 of 25000 complete in 63.9 sec
#  [                  0%                  ] 196 of 25000 complete in 64.5 sec
#  [                  0%                  ] 198 of 25000 complete in 65.4 sec
#  [                  0%                  ] 201 of 25000 complete in 66.2 sec
#  [                  0%                  ] 203 of 25000 complete in 66.7 sec
#  [                  0%                  ] 206 of 25000 complete in 67.3 sec
#  [                  0%                  ] 208 of 25000 complete in 67.9 sec
#  [                  0%                  ] 210 of 25000 complete in 68.5 sec
#  [                  0%                  ] 213 of 25000 complete in 69.2 sec
#  [                  0%                  ] 217 of 25000 complete in 69.9 sec
#  [                  0%                  ] 220 of 25000 complete in 70.4 sec
#  [                  0%                  ] 224 of 25000 complete in 71.4 sec
#  [                  0%                  ] 226 of 25000 complete in 72.6 sec
#  [                  0%                  ] 228 of 25000 complete in 73.3 sec
#  [                  0%                  ] 230 of 25000 complete in 73.9 sec
#  [                  0%                  ] 233 of 25000 complete in 74.7 sec
#  [                  0%                  ] 238 of 25000 complete in 75.4 sec
#  [                  0%                  ] 241 of 25000 complete in 76.1 sec
#  [                  0%                  ] 245 of 25000 complete in 76.6 sec
#  [                  0%                  ] 249 of 25000 complete in 77.2 sec
#  [                  1%                  ] 251 of 25000 complete in 77.9 sec
#  [                  1%                  ] 254 of 25000 complete in 78.4 sec
#  [                  1%                  ] 255 of 25000 complete in 79.2 sec
#  [                  1%                  ] 258 of 25000 complete in 79.8 sec
#  [                  1%                  ] 259 of 25000 complete in 80.5 sec
#  [                  1%                  ] 262 of 25000 complete in 81.1 sec
#  [                  1%                  ] 265 of 25000 complete in 81.7 sec
#  [                  1%                  ] 268 of 25000 complete in 82.3 sec
#  [                  1%                  ] 271 of 25000 complete in 82.9 sec
#  [                  1%                  ] 273 of 25000 complete in 83.7 sec
#  [                  1%                  ] 275 of 25000 complete in 84.7 sec
#  [                  1%                  ] 278 of 25000 complete in 85.7 sec
#  [                  1%                  ] 279 of 25000 complete in 86.5 sec
#  [                  1%                  ] 281 of 25000 complete in 87.6 sec
#  [                  1%                  ] 283 of 25000 complete in 88.2 sec
#  [                  1%                  ] 285 of 25000 complete in 88.7 sec
#  [                  1%                  ] 286 of 25000 complete in 89.3 sec
#  [                  1%                  ] 288 of 25000 complete in 90.1 sec
#  [                  1%                  ] 291 of 25000 complete in 90.7 sec
#  [                  1%                  ] 294 of 25000 complete in 91.2 sec
#  [                  1%                  ] 296 of 25000 complete in 91.7 sec
#  [                  1%                  ] 299 of 25000 complete in 92.2 sec
#  [                  1%                  ] 300 of 25000 complete in 93.0 sec
#  [                  1%                  ] 303 of 25000 complete in 93.9 sec
#  [                  1%                  ] 306 of 25000 complete in 94.7 sec
#  [                  1%                  ] 309 of 25000 complete in 95.4 sec
#  [                  1%                  ] 311 of 25000 complete in 96.2 sec
#  [                  1%                  ] 313 of 25000 complete in 96.9 sec
#  [                  1%                  ] 316 of 25000 complete in 97.9 sec
#  [                  1%                  ] 317 of 25000 complete in 98.5 sec
#  [                  1%                  ] 319 of 25000 complete in 99.2 sec
#  [                  1%                  ] 321 of 25000 complete in 99.8 sec
#  [                  1%                  ] 324 of 25000 complete in 101.9 sec
#  [                  1%                  ] 325 of 25000 complete in 102.5 sec
#  [                  1%                  ] 327 of 25000 complete in 103.2 sec
#  [                  1%                  ] 330 of 25000 complete in 103.7 sec
#  [                  1%                  ] 331 of 25000 complete in 104.5 sec
#  [                  1%                  ] 333 of 25000 complete in 105.0 sec
#  [                  1%                  ] 336 of 25000 complete in 105.7 sec
#  [                  1%                  ] 338 of 25000 complete in 106.5 sec
#  [                  1%                  ] 341 of 25000 complete in 107.6 sec
#  [                  1%                  ] 344 of 25000 complete in 108.2 sec
#  [                  1%                  ] 347 of 25000 complete in 109.0 sec
#  [                  1%                  ] 350 of 25000 complete in 109.6 sec
#  [                  1%                  ] 353 of 25000 complete in 110.5 sec
#  [                  1%                  ] 357 of 25000 complete in 111.0 sec
#  [                  1%                  ] 361 of 25000 complete in 111.6 sec
#  [                  1%                  ] 365 of 25000 complete in 112.7 sec
#  [                  1%                  ] 368 of 25000 complete in 113.3 sec
#  [                  1%                  ] 370 of 25000 complete in 113.8 sec
#  [                  1%                  ] 373 of 25000 complete in 114.4 sec
#  [                  1%                  ] 376 of 25000 complete in 115.1 sec
#  [                  1%                  ] 378 of 25000 complete in 115.9 sec
#  [                  1%                  ] 381 of 25000 complete in 116.7 sec
#  [                  1%                  ] 383 of 25000 complete in 117.3 sec
#  [                  1%                  ] 386 of 25000 complete in 118.3 sec
#  [                  1%                  ] 387 of 25000 complete in 119.1 sec
#  [                  1%                  ] 390 of 25000 complete in 119.6 sec
#  [                  1%                  ] 391 of 25000 complete in 120.4 sec
#  [                  1%                  ] 394 of 25000 complete in 121.5 sec
#  [                  1%                  ] 396 of 25000 complete in 122.2 sec
#  [                  1%                  ] 398 of 25000 complete in 122.7 sec
#  [                  1%                  ] 400 of 25000 complete in 123.6 sec
#  [                  1%                  ] 403 of 25000 complete in 124.1 sec
#  [                  1%                  ] 405 of 25000 complete in 124.7 sec
#  [                  1%                  ] 407 of 25000 complete in 125.5 sec
#  [                  1%                  ] 409 of 25000 complete in 126.4 sec
#  [                  1%                  ] 412 of 25000 complete in 126.9 sec
#  [                  1%                  ] 417 of 25000 complete in 128.1 sec
#  [                  1%                  ] 420 of 25000 complete in 128.9 sec
#  [                  1%                  ] 424 of 25000 complete in 129.6 sec
#  [                  1%                  ] 430 of 25000 complete in 130.8 sec
#  [                  1%                  ] 432 of 25000 complete in 131.6 sec
#  [                  1%                  ] 435 of 25000 complete in 132.3 sec
#  [                  1%                  ] 438 of 25000 complete in 133.0 sec
#  [                  1%                  ] 441 of 25000 complete in 134.2 sec
#  [                  1%                  ] 444 of 25000 complete in 135.1 sec
#  [                  1%                  ] 447 of 25000 complete in 135.6 sec
#  [                  1%                  ] 449 of 25000 complete in 136.6 sec
#  [                  1%                  ] 451 of 25000 complete in 137.2 sec
#  [                  1%                  ] 456 of 25000 complete in 137.8 sec
#  [                  1%                  ] 460 of 25000 complete in 138.4 sec
#  [                  1%                  ] 461 of 25000 complete in 139.3 sec
#  [                  1%                  ] 465 of 25000 complete in 139.8 sec
#  [                  1%                  ] 468 of 25000 complete in 140.4 sec
#  [                  1%                  ] 471 of 25000 complete in 141.0 sec
#  [                  1%                  ] 474 of 25000 complete in 141.6 sec
#  [                  1%                  ] 476 of 25000 complete in 142.5 sec
#  [                  1%                  ] 479 of 25000 complete in 143.1 sec
#  [                  1%                  ] 483 of 25000 complete in 143.9 sec
#  [                  1%                  ] 486 of 25000 complete in 144.4 sec
#  [                  1%                  ] 489 of 25000 complete in 145.0 sec
#  [                  1%                  ] 492 of 25000 complete in 145.6 sec
#  [                  1%                  ] 495 of 25000 complete in 146.4 sec
#  [                  1%                  ] 497 of 25000 complete in 147.5 sec
#  [                  1%                  ] 499 of 25000 complete in 148.0 sec
#  [                  2%                  ] 502 of 25000 complete in 148.9 sec
#  [                  2%                  ] 505 of 25000 complete in 150.0 sec
#  [                  2%                  ] 509 of 25000 complete in 150.6 sec
#  [                  2%                  ] 512 of 25000 complete in 151.6 sec
#  [                  2%                  ] 518 of 25000 complete in 152.3 sec
#  [                  2%                  ] 520 of 25000 complete in 152.9 sec
#  [                  2%                  ] 524 of 25000 complete in 153.5 sec
#  [                  2%                  ] 527 of 25000 complete in 154.8 sec
#  [                  2%                  ] 529 of 25000 complete in 155.4 sec
#  [                  2%                  ] 531 of 25000 complete in 155.9 sec
#  [                  2%                  ] 533 of 25000 complete in 157.1 sec
#  [                  2%                  ] 535 of 25000 complete in 157.7 sec
#  [                  2%                  ] 538 of 25000 complete in 158.3 sec
#  [                  2%                  ] 540 of 25000 complete in 159.0 sec
#  [                  2%                  ] 543 of 25000 complete in 159.5 sec
#  [                  2%                  ] 545 of 25000 complete in 160.2 sec
#  [                  2%                  ] 548 of 25000 complete in 160.8 sec
#  [                  2%                  ] 550 of 25000 complete in 161.7 sec
#  [                  2%                  ] 553 of 25000 complete in 162.2 sec
#  [                  2%                  ] 556 of 25000 complete in 162.8 sec
#  [                  2%                  ] 558 of 25000 complete in 163.3 sec
#  [                  2%                  ] 561 of 25000 complete in 164.0 sec
#  [                  2%                  ] 563 of 25000 complete in 164.6 sec
#  [                  2%                  ] 565 of 25000 complete in 165.4 sec
#  [                  2%                  ] 568 of 25000 complete in 166.0 sec
#  [                  2%                  ] 570 of 25000 complete in 166.5 sec
#  [                  2%                  ] 573 of 25000 complete in 167.1 sec
#  [                  2%                  ] 576 of 25000 complete in 168.1 sec
#  [                  2%                  ] 579 of 25000 complete in 169.0 sec
#  [                  2%                  ] 581 of 25000 complete in 169.8 sec
#  [                  2%                  ] 584 of 25000 complete in 170.4 sec
#  [                  2%                  ] 587 of 25000 complete in 171.0 sec
#  [                  2%                  ] 589 of 25000 complete in 171.5 sec
#  [                  2%                  ] 592 of 25000 complete in 172.3 sec
#  [                  2%                  ] 593 of 25000 complete in 173.1 sec
#  [                  2%                  ] 595 of 25000 complete in 173.6 sec
#  [                  2%                  ] 598 of 25000 complete in 174.6 sec
#  [                  2%                  ] 601 of 25000 complete in 175.1 sec
#  [                  2%                  ] 603 of 25000 complete in 175.9 sec
#  [                  2%                  ] 606 of 25000 complete in 176.6 sec
#  [                  2%                  ] 609 of 25000 complete in 177.2 sec
#  [                  2%                  ] 611 of 25000 complete in 177.7 sec
#  [                  2%                  ] 613 of 25000 complete in 178.4 sec
#  [                  2%                  ] 616 of 25000 complete in 179.2 sec
#  [                  2%                  ] 619 of 25000 complete in 179.8 sec
#  [                  2%                  ] 623 of 25000 complete in 180.3 sec
#  [                  2%                  ] 625 of 25000 complete in 181.1 sec
#  [                  2%                  ] 628 of 25000 complete in 182.0 sec
#  [                  2%                  ] 633 of 25000 complete in 182.8 sec
#  [                  2%                  ] 636 of 25000 complete in 183.8 sec
#  [                  2%                  ] 639 of 25000 complete in 184.3 sec
#  [                  2%                  ] 640 of 25000 complete in 184.8 sec
#  [                  2%                  ] 643 of 25000 complete in 185.4 sec
#  [                  2%                  ] 647 of 25000 complete in 189.1 sec
#  [                  2%                  ] 649 of 25000 complete in 190.1 sec
#  [                  2%                  ] 650 of 25000 complete in 190.9 sec
#  [                  2%                  ] 652 of 25000 complete in 191.5 sec
#  [                  2%                  ] 653 of 25000 complete in 192.0 sec
#  [                  2%                  ] 657 of 25000 complete in 193.3 sec
#  [-                 2%                  ] 660 of 25000 complete in 194.0 sec
#  [-                 2%                  ] 663 of 25000 complete in 194.7 sec
#  [-                 2%                  ] 664 of 25000 complete in 195.2 sec
#  [-                 2%                  ] 667 of 25000 complete in 195.9 sec
#  [-                 2%                  ] 669 of 25000 complete in 196.4 sec
#  [-                 2%                  ] 671 of 25000 complete in 197.0 sec
#  [-                 2%                  ] 675 of 25000 complete in 198.0 sec
#  [-                 2%                  ] 677 of 25000 complete in 198.6 sec
#  [-                 2%                  ] 681 of 25000 complete in 199.4 sec
#  [-                 2%                  ] 683 of 25000 complete in 200.0 sec
#  [-                 2%                  ] 685 of 25000 complete in 200.6 sec
#  [-                 2%                  ] 687 of 25000 complete in 201.4 sec
#  [-                 2%                  ] 689 of 25000 complete in 201.9 sec
#  [-                 2%                  ] 690 of 25000 complete in 202.7 sec
#  [-                 2%                  ] 691 of 25000 complete in 203.5 sec
#  [-                 2%                  ] 694 of 25000 complete in 204.7 sec
#  [-                 2%                  ] 696 of 25000 complete in 205.3 sec
#  [-                 2%                  ] 698 of 25000 complete in 206.1 sec
#  [-                 2%                  ] 702 of 25000 complete in 206.7 sec
#  [-                 2%                  ] 704 of 25000 complete in 207.4 sec
#  [-                 2%                  ] 708 of 25000 complete in 208.1 sec
#  [-                 2%                  ] 711 of 25000 complete in 208.8 sec
#  [-                 2%                  ] 715 of 25000 complete in 209.8 sec
#  [-                 2%                  ] 716 of 25000 complete in 210.7 sec
#  [-                 2%                  ] 719 of 25000 complete in 211.5 sec
#  [-                 2%                  ] 720 of 25000 complete in 212.3 sec
#  [-                 2%                  ] 725 of 25000 complete in 213.5 sec
#  [-                 2%                  ] 728 of 25000 complete in 214.1 sec
#  [-                 2%                  ] 730 of 25000 complete in 214.7 sec
#  [-                 2%                  ] 732 of 25000 complete in 215.5 sec
#  [-                 2%                  ] 736 of 25000 complete in 216.1 sec
#  [-                 2%                  ] 739 of 25000 complete in 217.0 sec
#  [-                 2%                  ] 742 of 25000 complete in 217.7 sec
#  [-                 2%                  ] 746 of 25000 complete in 218.2 sec
#  [-                 2%                  ] 748 of 25000 complete in 218.8 sec
#  [-                 2%                  ] 749 of 25000 complete in 219.3 sec
#  [-                 3%                  ] 751 of 25000 complete in 220.3 sec
#  [-                 3%                  ] 755 of 25000 complete in 221.4 sec
#  [-                 3%                  ] 757 of 25000 complete in 222.0 sec
#  [-                 3%                  ] 759 of 25000 complete in 222.8 sec
#  [-                 3%                  ] 761 of 25000 complete in 223.7 sec
#  [-                 3%                  ] 762 of 25000 complete in 224.5 sec
#  [-                 3%                  ] 764 of 25000 complete in 225.3 sec
#  [-                 3%                  ] 767 of 25000 complete in 226.0 sec
#  [-                 3%                  ] 772 of 25000 complete in 226.5 sec
#  [-                 3%                  ] 775 of 25000 complete in 227.4 sec
#  [-                 3%                  ] 777 of 25000 complete in 228.0 sec
#  [-                 3%                  ] 779 of 25000 complete in 228.7 sec
#  [-                 3%                  ] 780 of 25000 complete in 229.6 sec
#  [-                 3%                  ] 783 of 25000 complete in 230.4 sec
#  [-                 3%                  ] 785 of 25000 complete in 231.1 sec
#  [-                 3%                  ] 787 of 25000 complete in 232.4 sec
#  [-                 3%                  ] 789 of 25000 complete in 233.1 sec
#  [-                 3%                  ] 792 of 25000 complete in 233.8 sec
#  [-                 3%                  ] 794 of 25000 complete in 234.3 sec
#  [-                 3%                  ] 798 of 25000 complete in 235.2 sec
#  [-                 3%                  ] 801 of 25000 complete in 235.9 sec
#  [-                 3%                  ] 805 of 25000 complete in 236.4 sec
#  [-                 3%                  ] 808 of 25000 complete in 237.0 sec
#  [-                 3%                  ] 811 of 25000 complete in 237.8 sec
#  [-                 3%                  ] 813 of 25000 complete in 238.9 sec
#  [-                 3%                  ] 814 of 25000 complete in 239.8 sec
#  [-                 3%                  ] 816 of 25000 complete in 240.5 sec
#  [-                 3%                  ] 818 of 25000 complete in 241.2 sec
#  [-                 3%                  ] 821 of 25000 complete in 241.9 sec
#  [-                 3%                  ] 823 of 25000 complete in 242.4 sec
#  [-                 3%                  ] 827 of 25000 complete in 243.3 sec
#  [-                 3%                  ] 830 of 25000 complete in 243.9 sec
#  [-                 3%                  ] 833 of 25000 complete in 244.5 sec
#  [-                 3%                  ] 835 of 25000 complete in 245.3 sec
#  [-                 3%                  ] 836 of 25000 complete in 245.9 sec
#  [-                 3%                  ] 838 of 25000 complete in 246.5 sec
#  [-                 3%                  ] 840 of 25000 complete in 247.1 sec
#  [-                 3%                  ] 842 of 25000 complete in 247.9 sec
#  [-                 3%                  ] 844 of 25000 complete in 248.6 sec
#  [-                 3%                  ] 847 of 25000 complete in 249.3 sec
#  [-                 3%                  ] 850 of 25000 complete in 249.9 sec
#  [-                 3%                  ] 852 of 25000 complete in 250.5 sec
#  [-                 3%                  ] 855 of 25000 complete in 251.1 sec
#  [-                 3%                  ] 859 of 25000 complete in 252.3 sec
#  [-                 3%                  ] 862 of 25000 complete in 253.2 sec
#  [-                 3%                  ] 864 of 25000 complete in 253.8 sec
#  [-                 3%                  ] 866 of 25000 complete in 254.5 sec
#  [-                 3%                  ] 869 of 25000 complete in 255.7 sec
#  [-                 3%                  ] 871 of 25000 complete in 256.5 sec
#  [-                 3%                  ] 873 of 25000 complete in 257.3 sec
#  [-                 3%                  ] 875 of 25000 complete in 258.0 sec
#  [-                 3%                  ] 878 of 25000 complete in 258.8 sec
#  [-                 3%                  ] 880 of 25000 complete in 259.6 sec
#  [-                 3%                  ] 885 of 25000 complete in 260.5 sec
#  [-                 3%                  ] 886 of 25000 complete in 261.4 sec
#  [-                 3%                  ] 888 of 25000 complete in 262.0 sec
#  [-                 3%                  ] 892 of 25000 complete in 262.7 sec
#  [-                 3%                  ] 893 of 25000 complete in 263.3 sec
#  [-                 3%                  ] 895 of 25000 complete in 263.8 sec
#  [-                 3%                  ] 896 of 25000 complete in 264.7 sec
#  [-                 3%                  ] 899 of 25000 complete in 265.3 sec
#  [-                 3%                  ] 902 of 25000 complete in 265.9 sec
#  [-                 3%                  ] 903 of 25000 complete in 266.8 sec
#  [-                 3%                  ] 905 of 25000 complete in 267.5 sec
#  [-                 3%                  ] 909 of 25000 complete in 268.3 sec
#  [-                 3%                  ] 911 of 25000 complete in 269.2 sec
#  [-                 3%                  ] 914 of 25000 complete in 269.9 sec
#  [-                 3%                  ] 915 of 25000 complete in 270.9 sec
#  [-                 3%                  ] 918 of 25000 complete in 272.2 sec
#  [-                 3%                  ] 919 of 25000 complete in 272.7 sec
#  [-                 3%                  ] 920 of 25000 complete in 273.3 sec
#  [-                 3%                  ] 922 of 25000 complete in 274.3 sec
#  [-                 3%                  ] 924 of 25000 complete in 275.1 sec
#  [-                 3%                  ] 926 of 25000 complete in 275.8 sec
#  [-                 3%                  ] 928 of 25000 complete in 276.4 sec
#  [-                 3%                  ] 929 of 25000 complete in 276.9 sec
#  [-                 3%                  ] 931 of 25000 complete in 278.0 sec
#  [-                 3%                  ] 934 of 25000 complete in 279.4 sec
#  [-                 3%                  ] 935 of 25000 complete in 280.0 sec
#  [-                 3%                  ] 936 of 25000 complete in 280.5 sec
#  [-                 3%                  ] 939 of 25000 complete in 281.4 sec
#  [-                 3%                  ] 941 of 25000 complete in 282.0 sec
#  [-                 3%                  ] 944 of 25000 complete in 282.8 sec
#  [-                 3%                  ] 948 of 25000 complete in 283.8 sec
#  [-                 3%                  ] 950 of 25000 complete in 284.4 sec
#  [-                 3%                  ] 954 of 25000 complete in 286.0 sec
#  [-                 3%                  ] 955 of 25000 complete in 286.5 sec
#  [-                 3%                  ] 956 of 25000 complete in 287.1 sec
#  [-                 3%                  ] 957 of 25000 complete in 287.6 sec
#  [-                 3%                  ] 958 of 25000 complete in 288.6 sec
#  [-                 3%                  ] 959 of 25000 complete in 289.2 sec
#  [-                 3%                  ] 963 of 25000 complete in 290.2 sec
#  [-                 3%                  ] 964 of 25000 complete in 291.3 sec
#  [-                 3%                  ] 965 of 25000 complete in 291.8 sec
#  [-                 3%                  ] 970 of 25000 complete in 292.7 sec
#  [-                 3%                  ] 974 of 25000 complete in 293.4 sec
#  [-                 3%                  ] 977 of 25000 complete in 294.0 sec
#  [-                 3%                  ] 978 of 25000 complete in 294.5 sec
#  [-                 3%                  ] 981 of 25000 complete in 295.2 sec
#  [-                 3%                  ] 985 of 25000 complete in 296.0 sec
#  [-                 3%                  ] 990 of 25000 complete in 297.0 sec
#  [-                 3%                  ] 991 of 25000 complete in 297.8 sec
#  [-                 3%                  ] 992 of 25000 complete in 298.3 sec
#  [-                 3%                  ] 993 of 25000 complete in 299.4 sec
#  [-                 3%                  ] 995 of 25000 complete in 300.0 sec
#  [-                 3%                  ] 996 of 25000 complete in 300.6 sec
#  [-                 4%                  ] 1001 of 25000 complete in 301.2 sec
#  [-                 4%                  ] 1003 of 25000 complete in 302.1 sec
#  [-                 4%                  ] 1005 of 25000 complete in 303.5 sec
#  [-                 4%                  ] 1006 of 25000 complete in 304.1 sec
#  [-                 4%                  ] 1008 of 25000 complete in 304.6 sec
#  [-                 4%                  ] 1009 of 25000 complete in 305.2 sec
#  [-                 4%                  ] 1010 of 25000 complete in 305.7 sec
#  [-                 4%                  ] 1013 of 25000 complete in 306.4 sec
#  [-                 4%                  ] 1014 of 25000 complete in 307.0 sec
#  [-                 4%                  ] 1016 of 25000 complete in 307.5 sec
#  [-                 4%                  ] 1018 of 25000 complete in 308.5 sec
#  [-                 4%                  ] 1019 of 25000 complete in 309.1 sec
#  [-                 4%                  ] 1020 of 25000 complete in 309.8 sec
#  [-                 4%                  ] 1024 of 25000 complete in 310.8 sec
#  [-                 4%                  ] 1025 of 25000 complete in 311.5 sec
#  [-                 4%                  ] 1026 of 25000 complete in 312.1 sec
#  [-                 4%                  ] 1028 of 25000 complete in 313.5 sec
#  [-                 4%                  ] 1029 of 25000 complete in 314.2 sec
#  [-                 4%                  ] 1030 of 25000 complete in 314.8 sec
#  [-                 4%                  ] 1031 of 25000 complete in 316.2 sec
#  [-                 4%                  ] 1032 of 25000 complete in 316.7 sec
#  [-                 4%                  ] 1034 of 25000 complete in 317.3 sec
#  [-                 4%                  ] 1035 of 25000 complete in 317.9 sec
#  [-                 4%                  ] 1036 of 25000 complete in 318.8 sec
#  [-                 4%                  ] 1039 of 25000 complete in 319.7 sec
#  [-                 4%                  ] 1040 of 25000 complete in 320.3 sec
#  [-                 4%                  ] 1041 of 25000 complete in 322.1 sec
#  [-                 4%                  ] 1042 of 25000 complete in 322.9 sec
#  [-                 4%                  ] 1043 of 25000 complete in 323.7 sec
#  [-                 4%                  ] 1044 of 25000 complete in 324.5 sec
#  [-                 4%                  ] 1046 of 25000 complete in 325.7 sec
#  [-                 4%                  ] 1049 of 25000 complete in 326.3 sec
#  [-                 4%                  ] 1052 of 25000 complete in 328.3 sec
#  [-                 4%                  ] 1055 of 25000 complete in 329.1 sec
#  [-                 4%                  ] 1056 of 25000 complete in 329.8 sec
#  [-                 4%                  ] 1059 of 25000 complete in 331.0 sec
#  [-                 4%                  ] 1060 of 25000 complete in 332.0 sec
#  [-                 4%                  ] 1061 of 25000 complete in 333.0 sec
#  [-                 4%                  ] 1062 of 25000 complete in 334.0 sec
#  [-                 4%                  ] 1064 of 25000 complete in 335.5 sec
#  [-                 4%                  ] 1065 of 25000 complete in 336.3 sec
#  [-                 4%                  ] 1066 of 25000 complete in 336.8 sec
#  [-                 4%                  ] 1067 of 25000 complete in 338.8 sec
#  [-                 4%                  ] 1068 of 25000 complete in 339.8 sec
#  [-                 4%                  ] 1069 of 25000 complete in 340.8 sec
#  [-                 4%                  ] 1071 of 25000 complete in 341.5 sec
#  [-                 4%                  ] 1073 of 25000 complete in 342.5 sec
#  [-                 4%                  ] 1074 of 25000 complete in 343.0 sec
#  [-                 4%                  ] 1076 of 25000 complete in 343.9 sec
#  [-                 4%                  ] 1078 of 25000 complete in 346.9 sec
#  [-                 4%                  ] 1079 of 25000 complete in 349.9 sec
#  [-                 4%                  ] 1081 of 25000 complete in 351.7 sec
#  [-                 4%                  ] 1083 of 25000 complete in 352.3 sec
#  [-                 4%                  ] 1087 of 25000 complete in 353.2 sec
#  [-                 4%                  ] 1090 of 25000 complete in 354.3 sec
#  [-                 4%                  ] 1092 of 25000 complete in 355.4 sec
#  [-                 4%                  ] 1093 of 25000 complete in 356.2 sec
#  [-                 4%                  ] 1095 of 25000 complete in 357.3 sec
#  [-                 4%                  ] 1097 of 25000 complete in 358.5 sec
#  [-                 4%                  ] 1099 of 25000 complete in 359.3 sec
#  [-                 4%                  ] 1101 of 25000 complete in 359.9 sec
#  [-                 4%                  ] 1103 of 25000 complete in 360.4 sec
#  [-                 4%                  ] 1106 of 25000 complete in 361.2 sec
#  [-                 4%                  ] 1111 of 25000 complete in 361.9 sec
#  [-                 4%                  ] 1114 of 25000 complete in 362.7 sec
#  [-                 4%                  ] 1118 of 25000 complete in 363.8 sec
#  [-                 4%                  ] 1121 of 25000 complete in 364.4 sec
#  [-                 4%                  ] 1124 of 25000 complete in 365.1 sec
#  [-                 4%                  ] 1125 of 25000 complete in 365.9 sec
#  [-                 4%                  ] 1127 of 25000 complete in 366.9 sec
#  [-                 4%                  ] 1129 of 25000 complete in 367.6 sec
#  [-                 4%                  ] 1132 of 25000 complete in 368.2 sec
#  [-                 4%                  ] 1136 of 25000 complete in 368.8 sec
#  [-                 4%                  ] 1139 of 25000 complete in 369.6 sec
#  [-                 4%                  ] 1142 of 25000 complete in 370.4 sec
#  [-                 4%                  ] 1145 of 25000 complete in 371.3 sec
#  [-                 4%                  ] 1147 of 25000 complete in 371.8 sec
#  [-                 4%                  ] 1150 of 25000 complete in 372.5 sec
#  [-                 4%                  ] 1152 of 25000 complete in 373.4 sec
#  [-                 4%                  ] 1154 of 25000 complete in 374.0 sec
#  [-                 4%                  ] 1157 of 25000 complete in 375.1 sec
#  [-                 4%                  ] 1160 of 25000 complete in 375.7 sec
#  [-                 4%                  ] 1162 of 25000 complete in 376.5 sec
#  [-                 4%                  ] 1165 of 25000 complete in 377.2 sec
#  [-                 4%                  ] 1170 of 25000 complete in 377.8 sec
#  [-                 4%                  ] 1172 of 25000 complete in 378.9 sec
#  [-                 4%                  ] 1173 of 25000 complete in 379.7 sec
#  [-                 4%                  ] 1176 of 25000 complete in 380.3 sec
#  [-                 4%                  ] 1179 of 25000 complete in 380.9 sec
#  [-                 4%                  ] 1181 of 25000 complete in 381.5 sec
#  [-                 4%                  ] 1184 of 25000 complete in 382.1 sec
#  [-                 4%                  ] 1186 of 25000 complete in 382.9 sec
#  [-                 4%                  ] 1189 of 25000 complete in 383.5 sec
#  [-                 4%                  ] 1192 of 25000 complete in 384.3 sec
#  [-                 4%                  ] 1197 of 25000 complete in 385.1 sec
#  [-                 4%                  ] 1200 of 25000 complete in 385.7 sec
#  [-                 4%                  ] 1201 of 25000 complete in 386.5 sec
#  [-                 4%                  ] 1203 of 25000 complete in 387.3 sec
#  [-                 4%                  ] 1205 of 25000 complete in 388.4 sec
#  [-                 4%                  ] 1208 of 25000 complete in 389.1 sec
#  [-                 4%                  ] 1212 of 25000 complete in 390.4 sec
#  [-                 4%                  ] 1216 of 25000 complete in 391.5 sec
#  [-                 4%                  ] 1220 of 25000 complete in 392.3 sec
#  [-                 4%                  ] 1221 of 25000 complete in 393.0 sec
#  [-                 4%                  ] 1223 of 25000 complete in 393.8 sec
#  [-                 4%                  ] 1226 of 25000 complete in 394.6 sec
#  [-                 4%                  ] 1228 of 25000 complete in 395.2 sec
#  [-                 4%                  ] 1231 of 25000 complete in 395.7 sec
#  [-                 4%                  ] 1234 of 25000 complete in 396.5 sec
#  [-                 4%                  ] 1237 of 25000 complete in 397.1 sec
#  [-                 4%                  ] 1240 of 25000 complete in 397.9 sec
#  [-                 4%                  ] 1244 of 25000 complete in 398.5 sec
#  [-                 4%                  ] 1246 of 25000 complete in 399.4 sec
#  [-                 4%                  ] 1248 of 25000 complete in 400.0 sec
#  [-                 5%                  ] 1250 of 25000 complete in 400.7 sec
#  [-                 5%                  ] 1252 of 25000 complete in 401.4 sec
#  [-                 5%                  ] 1253 of 25000 complete in 402.2 sec
#  [-                 5%                  ] 1255 of 25000 complete in 403.0 sec
#  [-                 5%                  ] 1257 of 25000 complete in 403.8 sec
#  [-                 5%                  ] 1259 of 25000 complete in 404.3 sec
#  [-                 5%                  ] 1261 of 25000 complete in 405.0 sec
#  [-                 5%                  ] 1263 of 25000 complete in 405.6 sec
#  [-                 5%                  ] 1266 of 25000 complete in 406.5 sec
#  [-                 5%                  ] 1269 of 25000 complete in 407.1 sec
#  [-                 5%                  ] 1272 of 25000 complete in 407.9 sec
#  [-                 5%                  ] 1275 of 25000 complete in 408.5 sec
#  [-                 5%                  ] 1277 of 25000 complete in 409.1 sec
#  [-                 5%                  ] 1280 of 25000 complete in 409.6 sec
#  [-                 5%                  ] 1284 of 25000 complete in 410.3 sec
#  [-                 5%                  ] 1289 of 25000 complete in 410.9 sec
#  [-                 5%                  ] 1291 of 25000 complete in 411.6 sec
#  [-                 5%                  ] 1292 of 25000 complete in 412.2 sec
#  [-                 5%                  ] 1295 of 25000 complete in 412.7 sec
#  [-                 5%                  ] 1298 of 25000 complete in 413.7 sec
#  [-                 5%                  ] 1300 of 25000 complete in 414.3 sec
#  [-                 5%                  ] 1303 of 25000 complete in 415.1 sec
#  [-                 5%                  ] 1305 of 25000 complete in 416.0 sec
#  [-                 5%                  ] 1307 of 25000 complete in 416.7 sec
#  [-                 5%                  ] 1309 of 25000 complete in 417.3 sec
#  [-                 5%                  ] 1311 of 25000 complete in 417.8 sec
#  [-                 5%                  ] 1312 of 25000 complete in 418.6 sec
#  [-                 5%                  ] 1315 of 25000 complete in 419.3 sec
#  [--                5%                  ] 1318 of 25000 complete in 419.8 sec
#  [--                5%                  ] 1320 of 25000 complete in 420.4 sec
#  [--                5%                  ] 1322 of 25000 complete in 421.2 sec
#  [--                5%                  ] 1327 of 25000 complete in 421.8 sec
#  [--                5%                  ] 1328 of 25000 complete in 422.6 sec
#  [--                5%                  ] 1331 of 25000 complete in 423.4 sec
#  [--                5%                  ] 1338 of 25000 complete in 424.2 sec
#  [--                5%                  ] 1340 of 25000 complete in 424.9 sec
#  [--                5%                  ] 1342 of 25000 complete in 425.6 sec
#  [--                5%                  ] 1344 of 25000 complete in 426.4 sec
#  [--                5%                  ] 1348 of 25000 complete in 427.0 sec
#  [--                5%                  ] 1350 of 25000 complete in 427.6 sec
#  [--                5%                  ] 1352 of 25000 complete in 428.2 sec
#  [--                5%                  ] 1355 of 25000 complete in 429.4 sec
#  [--                5%                  ] 1359 of 25000 complete in 430.4 sec
#  [--                5%                  ] 1362 of 25000 complete in 431.0 sec
#  [--                5%                  ] 1364 of 25000 complete in 431.8 sec
#  [--                5%                  ] 1367 of 25000 complete in 432.5 sec
#  [--                5%                  ] 1371 of 25000 complete in 433.0 sec
#  [--                5%                  ] 1373 of 25000 complete in 433.7 sec
#  [--                5%                  ] 1375 of 25000 complete in 434.5 sec
#  [--                5%                  ] 1378 of 25000 complete in 435.3 sec
#  [--                5%                  ] 1382 of 25000 complete in 435.8 sec
#  [--                5%                  ] 1384 of 25000 complete in 436.6 sec
#  [--                5%                  ] 1386 of 25000 complete in 437.1 sec
#  [--                5%                  ] 1388 of 25000 complete in 437.9 sec
#  [--                5%                  ] 1390 of 25000 complete in 438.4 sec
#  [--                5%                  ] 1395 of 25000 complete in 439.2 sec
#  [--                5%                  ] 1397 of 25000 complete in 439.8 sec
#  [--                5%                  ] 1398 of 25000 complete in 440.6 sec
#  [--                5%                  ] 1401 of 25000 complete in 441.2 sec
#  [--                5%                  ] 1403 of 25000 complete in 441.7 sec
#  [--                5%                  ] 1405 of 25000 complete in 442.9 sec
#  [--                5%                  ] 1408 of 25000 complete in 443.4 sec
#  [--                5%                  ] 1413 of 25000 complete in 443.9 sec
#  [--                5%                  ] 1415 of 25000 complete in 444.9 sec
#  [--                5%                  ] 1418 of 25000 complete in 445.4 sec
#  [--                5%                  ] 1425 of 25000 complete in 445.9 sec
#  [--                5%                  ] 1429 of 25000 complete in 446.5 sec
#  [--                5%                  ] 1431 of 25000 complete in 447.6 sec
#  [--                5%                  ] 1434 of 25000 complete in 448.7 sec
#  [--                5%                  ] 1437 of 25000 complete in 449.6 sec
#  [--                5%                  ] 1440 of 25000 complete in 450.2 sec
#  [--                5%                  ] 1443 of 25000 complete in 450.8 sec
#  [--                5%                  ] 1446 of 25000 complete in 451.4 sec
#  [--                5%                  ] 1448 of 25000 complete in 451.9 sec
#  [--                5%                  ] 1451 of 25000 complete in 452.4 sec
#  [--                5%                  ] 1453 of 25000 complete in 453.4 sec
#  [--                5%                  ] 1454 of 25000 complete in 454.1 sec
#  [--                5%                  ] 1456 of 25000 complete in 454.6 sec
#  [--                5%                  ] 1460 of 25000 complete in 455.8 sec
#  [--                5%                  ] 1461 of 25000 complete in 456.6 sec
#  [--                5%                  ] 1465 of 25000 complete in 457.8 sec
#  [--                5%                  ] 1467 of 25000 complete in 458.3 sec
#  [--                5%                  ] 1469 of 25000 complete in 458.8 sec
#  [--                5%                  ] 1472 of 25000 complete in 459.5 sec
#  [--                5%                  ] 1474 of 25000 complete in 460.2 sec
#  [--                5%                  ] 1477 of 25000 complete in 460.8 sec
#  [--                5%                  ] 1480 of 25000 complete in 461.3 sec
#  [--                5%                  ] 1483 of 25000 complete in 462.1 sec
#  [--                5%                  ] 1487 of 25000 complete in 462.7 sec
#  [--                5%                  ] 1489 of 25000 complete in 463.2 sec
#  [--                5%                  ] 1492 of 25000 complete in 463.8 sec
#  [--                5%                  ] 1495 of 25000 complete in 464.3 sec
#  [--                5%                  ] 1497 of 25000 complete in 465.1 sec
#  [--                6%                  ] 1500 of 25000 complete in 465.7 sec
#  [--                6%                  ] 1503 of 25000 complete in 466.5 sec
#  [--                6%                  ] 1505 of 25000 complete in 467.1 sec
#  [--                6%                  ] 1507 of 25000 complete in 467.8 sec
#  [--                6%                  ] 1511 of 25000 complete in 468.3 sec
#  [--                6%                  ] 1513 of 25000 complete in 469.1 sec
#  [--                6%                  ] 1515 of 25000 complete in 469.6 sec
#  [--                6%                  ] 1517 of 25000 complete in 470.1 sec
#  [--                6%                  ] 1519 of 25000 complete in 470.9 sec
#  [--                6%                  ] 1523 of 25000 complete in 471.6 sec
#  [--                6%                  ] 1524 of 25000 complete in 472.3 sec
#  [--                6%                  ] 1527 of 25000 complete in 473.1 sec
#  [--                6%                  ] 1529 of 25000 complete in 473.8 sec
#  [--                6%                  ] 1532 of 25000 complete in 474.5 sec
#  [--                6%                  ] 1534 of 25000 complete in 475.1 sec
#  [--                6%                  ] 1536 of 25000 complete in 475.6 sec
#  [--                6%                  ] 1539 of 25000 complete in 476.4 sec
#  [--                6%                  ] 1542 of 25000 complete in 477.0 sec
#  [--                6%                  ] 1545 of 25000 complete in 477.7 sec
#  [--                6%                  ] 1546 of 25000 complete in 478.5 sec
#  [--                6%                  ] 1548 of 25000 complete in 479.3 sec
# ...
#  [-----------------97%----------------- ] 24389 of 25000 complete in 6412.0 sec
#  [-----------------97%----------------- ] 24392 of 25000 complete in 6412.5 sec
#  [-----------------97%----------------- ] 24395 of 25000 complete in 6413.2 sec
#  [-----------------97%----------------- ] 24399 of 25000 complete in 6413.7 sec
#  [-----------------97%----------------- ] 24401 of 25000 complete in 6414.5 sec
#  [-----------------97%----------------- ] 24402 of 25000 complete in 6415.3 sec
#  [-----------------97%----------------- ] 24404 of 25000 complete in 6415.8 sec
#  [-----------------97%----------------- ] 24407 of 25000 complete in 6416.6 sec
#  [-----------------97%----------------- ] 24410 of 25000 complete in 6417.3 sec
#  [-----------------97%----------------- ] 24411 of 25000 complete in 6418.0 sec
#  [-----------------97%----------------- ] 24415 of 25000 complete in 6418.7 sec
#  [-----------------97%----------------- ] 24419 of 25000 complete in 6419.3 sec
#  [-----------------97%----------------- ] 24422 of 25000 complete in 6419.8 sec
#  [-----------------97%----------------- ] 24427 of 25000 complete in 6420.6 sec
#  [-----------------97%----------------- ] 24431 of 25000 complete in 6421.3 sec
#  [-----------------97%----------------- ] 24434 of 25000 complete in 6422.1 sec
#  [-----------------97%----------------- ] 24437 of 25000 complete in 6422.9 sec
#  [-----------------97%----------------- ] 24441 of 25000 complete in 6423.5 sec
#  [-----------------97%----------------- ] 24443 of 25000 complete in 6424.1 sec
#  [-----------------97%----------------- ] 24445 of 25000 complete in 6424.7 sec
#  [-----------------97%----------------- ] 24448 of 25000 complete in 6425.3 sec
#  [-----------------97%----------------- ] 24453 of 25000 complete in 6426.0 sec
#  [-----------------97%----------------- ] 24456 of 25000 complete in 6426.7 sec
#  [-----------------97%----------------- ] 24458 of 25000 complete in 6427.3 sec
#  [-----------------97%----------------- ] 24459 of 25000 complete in 6428.0 sec
#  [-----------------97%----------------- ] 24463 of 25000 complete in 6428.8 sec
#  [-----------------97%----------------- ] 24464 of 25000 complete in 6429.5 sec
#  [-----------------97%----------------- ] 24467 of 25000 complete in 6430.1 sec
#  [-----------------97%----------------- ] 24470 of 25000 complete in 6430.8 sec
#  [-----------------97%----------------- ] 24473 of 25000 complete in 6431.5 sec
#  [-----------------97%----------------- ] 24475 of 25000 complete in 6432.1 sec
#  [-----------------97%----------------- ] 24480 of 25000 complete in 6432.6 sec
#  [-----------------97%----------------- ] 24484 of 25000 complete in 6433.2 sec
#  [-----------------97%----------------- ] 24486 of 25000 complete in 6433.8 sec
#  [-----------------97%----------------- ] 24489 of 25000 complete in 6434.3 sec
#  [-----------------97%----------------- ] 24492 of 25000 complete in 6435.1 sec
#  [-----------------97%----------------- ] 24495 of 25000 complete in 6435.8 sec
#  [-----------------97%----------------- ] 24498 of 25000 complete in 6436.5 sec
#  [-----------------98%----------------- ] 24500 of 25000 complete in 6437.1 sec
#  [-----------------98%----------------- ] 24502 of 25000 complete in 6437.8 sec
#  [-----------------98%----------------- ] 24505 of 25000 complete in 6438.3 sec
#  [-----------------98%----------------- ] 24510 of 25000 complete in 6439.1 sec
#  [-----------------98%----------------- ] 24514 of 25000 complete in 6440.2 sec
#  [-----------------98%----------------- ] 24516 of 25000 complete in 6440.8 sec
#  [-----------------98%----------------- ] 24519 of 25000 complete in 6441.5 sec
#  [-----------------98%----------------- ] 24521 of 25000 complete in 6442.1 sec
#  [-----------------98%----------------- ] 24524 of 25000 complete in 6442.8 sec
#  [-----------------98%----------------- ] 24527 of 25000 complete in 6443.4 sec
#  [-----------------98%----------------- ] 24531 of 25000 complete in 6444.0 sec
#  [-----------------98%----------------- ] 24534 of 25000 complete in 6444.9 sec
#  [-----------------98%----------------- ] 24536 of 25000 complete in 6445.5 sec
#  [-----------------98%----------------- ] 24539 of 25000 complete in 6446.1 sec
#  [-----------------98%----------------- ] 24541 of 25000 complete in 6447.1 sec
#  [-----------------98%----------------- ] 24545 of 25000 complete in 6448.2 sec
#  [-----------------98%----------------- ] 24547 of 25000 complete in 6448.9 sec
#  [-----------------98%----------------- ] 24549 of 25000 complete in 6449.6 sec
#  [-----------------98%----------------- ] 24552 of 25000 complete in 6450.3 sec
#  [-----------------98%----------------- ] 24554 of 25000 complete in 6450.8 sec
#  [-----------------98%----------------- ] 24558 of 25000 complete in 6451.4 sec
#  [-----------------98%----------------- ] 24560 of 25000 complete in 6451.9 sec
#  [-----------------98%----------------- ] 24566 of 25000 complete in 6452.6 sec
#  [-----------------98%----------------- ] 24572 of 25000 complete in 6453.3 sec
#  [-----------------98%----------------- ] 24574 of 25000 complete in 6453.9 sec
#  [-----------------98%----------------- ] 24576 of 25000 complete in 6454.6 sec
#  [-----------------98%----------------- ] 24579 of 25000 complete in 6455.3 sec
#  [-----------------98%----------------- ] 24582 of 25000 complete in 6455.9 sec
#  [-----------------98%----------------- ] 24583 of 25000 complete in 6456.6 sec
#  [-----------------98%----------------- ] 24584 of 25000 complete in 6457.3 sec
#  [-----------------98%----------------- ] 24586 of 25000 complete in 6458.0 sec
#  [-----------------98%----------------- ] 24588 of 25000 complete in 6458.7 sec
#  [-----------------98%----------------- ] 24591 of 25000 complete in 6459.4 sec
#  [-----------------98%----------------- ] 24594 of 25000 complete in 6460.1 sec
#  [-----------------98%----------------- ] 24597 of 25000 complete in 6460.7 sec
#  [-----------------98%----------------- ] 24601 of 25000 complete in 6461.5 sec
#  [-----------------98%----------------- ] 24604 of 25000 complete in 6462.3 sec
#  [-----------------98%----------------- ] 24607 of 25000 complete in 6462.9 sec
#  [-----------------98%----------------- ] 24611 of 25000 complete in 6463.4 sec
#  [-----------------98%----------------- ] 24615 of 25000 complete in 6463.9 sec
#  [-----------------98%----------------- ] 24619 of 25000 complete in 6464.7 sec
#  [-----------------98%----------------- ] 24623 of 25000 complete in 6465.4 sec
#  [-----------------98%----------------- ] 24627 of 25000 complete in 6466.1 sec
#  [-----------------98%----------------- ] 24631 of 25000 complete in 6466.7 sec
#  [-----------------98%----------------- ] 24633 of 25000 complete in 6467.4 sec
#  [-----------------98%----------------- ] 24635 of 25000 complete in 6468.0 sec
#  [-----------------98%----------------- ] 24639 of 25000 complete in 6468.8 sec
#  [-----------------98%----------------- ] 24645 of 25000 complete in 6469.5 sec
#  [-----------------98%----------------- ] 24647 of 25000 complete in 6470.1 sec
#  [-----------------98%----------------- ] 24649 of 25000 complete in 6471.0 sec
#  [-----------------98%----------------- ] 24652 of 25000 complete in 6471.5 sec
#  [-----------------98%----------------- ] 24656 of 25000 complete in 6472.2 sec
#  [-----------------98%----------------- ] 24660 of 25000 complete in 6473.3 sec
#  [-----------------98%----------------- ] 24663 of 25000 complete in 6474.4 sec
#  [-----------------98%----------------- ] 24666 of 25000 complete in 6475.1 sec
#  [-----------------98%----------------- ] 24667 of 25000 complete in 6475.8 sec
#  [-----------------98%----------------- ] 24674 of 25000 complete in 6476.4 sec
#  [-----------------98%----------------- ] 24678 of 25000 complete in 6477.1 sec
#  [-----------------98%----------------- ] 24681 of 25000 complete in 6477.7 sec
#  [-----------------98%----------------- ] 24684 of 25000 complete in 6478.3 sec
#  [-----------------98%----------------- ] 24686 of 25000 complete in 6479.0 sec
#  [-----------------98%----------------- ] 24687 of 25000 complete in 6479.6 sec
#  [-----------------98%----------------- ] 24690 of 25000 complete in 6480.5 sec
#  [-----------------98%----------------- ] 24694 of 25000 complete in 6481.2 sec
#  [-----------------98%----------------- ] 24697 of 25000 complete in 6481.7 sec
#  [-----------------98%----------------- ] 24700 of 25000 complete in 6482.4 sec
#  [-----------------98%----------------- ] 24703 of 25000 complete in 6483.1 sec
#  [-----------------98%----------------- ] 24705 of 25000 complete in 6483.9 sec
#  [-----------------98%----------------- ] 24709 of 25000 complete in 6484.4 sec
#  [-----------------98%----------------- ] 24712 of 25000 complete in 6485.3 sec
#  [-----------------98%----------------- ] 24716 of 25000 complete in 6486.1 sec
#  [-----------------98%----------------- ] 24718 of 25000 complete in 6486.7 sec
#  [-----------------98%----------------- ] 24720 of 25000 complete in 6487.5 sec
#  [-----------------98%----------------- ] 24726 of 25000 complete in 6488.1 sec
#  [-----------------98%----------------- ] 24732 of 25000 complete in 6488.9 sec
#  [-----------------98%----------------- ] 24735 of 25000 complete in 6489.4 sec
#  [-----------------98%----------------- ] 24737 of 25000 complete in 6490.0 sec
#  [-----------------98%----------------- ] 24741 of 25000 complete in 6490.5 sec
#  [-----------------98%----------------- ] 24749 of 25000 complete in 6491.3 sec
#  [-----------------99%----------------- ] 24752 of 25000 complete in 6491.8 sec
#  [-----------------99%----------------- ] 24755 of 25000 complete in 6492.6 sec
#  [-----------------99%----------------- ] 24761 of 25000 complete in 6493.2 sec
#  [-----------------99%----------------- ] 24764 of 25000 complete in 6493.8 sec
#  [-----------------99%----------------- ] 24767 of 25000 complete in 6494.5 sec
#  [-----------------99%----------------- ] 24771 of 25000 complete in 6495.3 sec
#  [-----------------99%----------------- ] 24774 of 25000 complete in 6495.8 sec
#  [-----------------99%----------------- ] 24775 of 25000 complete in 6496.5 sec
#  [-----------------99%----------------- ] 24778 of 25000 complete in 6497.0 sec
#  [-----------------99%----------------- ] 24780 of 25000 complete in 6497.6 sec
#  [-----------------99%----------------- ] 24782 of 25000 complete in 6498.2 sec
#  [-----------------99%----------------- ] 24784 of 25000 complete in 6499.0 sec
#  [-----------------99%----------------- ] 24786 of 25000 complete in 6499.6 sec
#  [-----------------99%----------------- ] 24792 of 25000 complete in 6500.5 sec
#  [-----------------99%----------------- ] 24795 of 25000 complete in 6501.1 sec
#  [-----------------99%----------------- ] 24796 of 25000 complete in 6501.9 sec
#  [-----------------99%----------------- ] 24800 of 25000 complete in 6502.5 sec
#  [-----------------99%----------------- ] 24802 of 25000 complete in 6503.1 sec
#  [-----------------99%----------------- ] 24805 of 25000 complete in 6503.9 sec
#  [-----------------99%----------------- ] 24809 of 25000 complete in 6504.5 sec
#  [-----------------99%----------------- ] 24812 of 25000 complete in 6505.2 sec
#  [-----------------99%----------------- ] 24816 of 25000 complete in 6506.0 sec
#  [-----------------99%----------------- ] 24818 of 25000 complete in 6506.5 sec
#  [-----------------99%----------------- ] 24821 of 25000 complete in 6507.1 sec
#  [-----------------99%----------------- ] 24824 of 25000 complete in 6507.6 sec
#  [-----------------99%----------------- ] 24827 of 25000 complete in 6508.3 sec
#  [-----------------99%----------------- ] 24831 of 25000 complete in 6509.1 sec
#  [-----------------99%----------------- ] 24833 of 25000 complete in 6509.7 sec
#  [-----------------99%----------------- ] 24837 of 25000 complete in 6510.5 sec
#  [-----------------99%----------------- ] 24840 of 25000 complete in 6511.1 sec
#  [-----------------99%----------------- ] 24844 of 25000 complete in 6511.6 sec
#  [-----------------99%----------------- ] 24847 of 25000 complete in 6512.4 sec
#  [-----------------99%----------------- ] 24850 of 25000 complete in 6512.9 sec
#  [-----------------99%----------------- ] 24856 of 25000 complete in 6513.5 sec
#  [-----------------99%----------------- ] 24859 of 25000 complete in 6514.3 sec
#  [-----------------99%----------------- ] 24861 of 25000 complete in 6514.9 sec
#  [-----------------99%----------------- ] 24862 of 25000 complete in 6515.6 sec
#  [-----------------99%----------------- ] 24864 of 25000 complete in 6516.3 sec
#  [-----------------99%----------------- ] 24866 of 25000 complete in 6516.9 sec
#  [-----------------99%----------------- ] 24869 of 25000 complete in 6517.5 sec
#  [-----------------99%----------------- ] 24873 of 25000 complete in 6518.0 sec
#  [-----------------99%----------------- ] 24875 of 25000 complete in 6518.6 sec
#  [-----------------99%----------------- ] 24877 of 25000 complete in 6519.2 sec
#  [-----------------99%----------------- ] 24880 of 25000 complete in 6519.7 sec
#  [-----------------99%----------------- ] 24884 of 25000 complete in 6520.9 sec
#  [-----------------99%----------------- ] 24889 of 25000 complete in 6521.7 sec
#  [-----------------99%----------------- ] 24893 of 25000 complete in 6522.4 sec
#  [-----------------99%----------------- ] 24895 of 25000 complete in 6523.1 sec
#  [-----------------99%----------------- ] 24898 of 25000 complete in 6523.8 sec
#  [-----------------99%----------------- ] 24899 of 25000 complete in 6524.5 sec
#  [-----------------99%----------------- ] 24906 of 25000 complete in 6525.1 sec
#  [-----------------99%----------------- ] 24907 of 25000 complete in 6525.8 sec
#  [-----------------99%----------------- ] 24910 of 25000 complete in 6526.6 sec
#  [-----------------99%----------------- ] 24912 of 25000 complete in 6527.2 sec
#  [-----------------99%----------------- ] 24915 of 25000 complete in 6527.9 sec
#  [-----------------99%----------------- ] 24920 of 25000 complete in 6528.6 sec
#  [-----------------99%----------------- ] 24923 of 25000 complete in 6529.3 sec
#  [-----------------99%----------------- ] 24926 of 25000 complete in 6529.8 sec
#  [-----------------99%----------------- ] 24930 of 25000 complete in 6530.3 sec
#  [-----------------99%----------------- ] 24932 of 25000 complete in 6531.1 sec
#  [-----------------99%----------------- ] 24934 of 25000 complete in 6531.6 sec
#  [-----------------99%----------------- ] 24936 of 25000 complete in 6532.3 sec
#  [-----------------99%----------------- ] 24937 of 25000 complete in 6532.9 sec
#  [-----------------99%----------------- ] 24940 of 25000 complete in 6533.7 sec
#  [-----------------99%----------------- ] 24944 of 25000 complete in 6534.4 sec
#  [-----------------99%----------------- ] 24948 of 25000 complete in 6535.5 sec
#  [-----------------99%----------------- ] 24951 of 25000 complete in 6536.0 sec
#  [-----------------99%----------------- ] 24954 of 25000 complete in 6536.8 sec
#  [-----------------99%----------------- ] 24959 of 25000 complete in 6537.3 sec
#  [-----------------99%----------------- ] 24960 of 25000 complete in 6538.0 sec
#  [-----------------99%----------------- ] 24963 of 25000 complete in 6538.6 sec
#  [-----------------99%----------------- ] 24965 of 25000 complete in 6539.6 sec
#  [-----------------99%----------------- ] 24968 of 25000 complete in 6540.2 sec
#  [-----------------99%----------------- ] 24971 of 25000 complete in 6541.0 sec
#  [-----------------99%----------------- ] 24975 of 25000 complete in 6541.5 sec
#  [-----------------99%----------------- ] 24979 of 25000 complete in 6542.1 sec
#  [-----------------99%----------------- ] 24982 of 25000 complete in 6542.9 sec
#  [-----------------99%----------------- ] 24986 of 25000 complete in 6543.7 sec
#  [-----------------99%----------------- ] 24989 of 25000 complete in 6544.4 sec
#  [-----------------99%----------------- ] 24991 of 25000 complete in 6545.0 sec
#  [-----------------99%----------------- ] 24994 of 25000 complete in 6545.7 sec
#  [-----------------100%-----------------] 25000 of 25000 complete in 6546.3 sec
#  [-----------------100%-----------------] 25000 of 25000 complete in 6546.6 sec

# %%
#############
### PLOTS ###
#############
#Remove the first n_steps from the trace
n_steps = 5000
#Plots of the posteriors and trace to check convergence beyond n_step.
traceplot(trace[n_steps:],['A','B','C','D']);

# %% [markdown]
# ##### Posteriors and fitting

# %%
#Data from trace to dataframe using pandas
df_trace = trace_to_dataframe(trace[n_steps:])

################
### Best fit ###
################
A_m     = stats.mode(df_trace.A)[0]
B_m     = stats.mode(df_trace.B)[0]
C_m     = stats.mode(df_trace.C)[0]
D_m     = stats.mode(df_trace.D)[0]

A_m = trace[n_steps:].get_values('A').mean()
B_m = trace[n_steps:].get_values('B').mean()
C_m = trace[n_steps:].get_values('C').mean()
D_m = trace[n_steps:].get_values('D').mean()


fa = fa_bn*l_bn
fe = fe_bn*l_bn

qa_bestfit = A_m*fa
qe_bestfit = B_m*fe
q_bestfit = qa_bestfit + qe_bestfit

ua_bestfit = C_m*fa
ue_bestfit = D_m*fe
u_bestfit = ua_bestfit + ue_bestfit


p_bestfit  = 100.*np.sqrt(q_bestfit*q_bestfit + u_bestfit*u_bestfit)
p_a_bestfit = 100.*np.sqrt(qa_bestfit*qa_bestfit + ua_bestfit*ua_bestfit) 
p_e_bestfit = 100.*np.sqrt(qe_bestfit*qe_bestfit + ue_bestfit*ue_bestfit) 

pa_bestfit   = 0.5*np.arctan(u_bestfit/q_bestfit)*180./3.1415 
pa_a_bestfit = 0.5*np.arctan(ua_bestfit/qa_bestfit)*180./3.1415 + zeros(len(l_bn))
pa_e_bestfit = 0.5*np.arctan(ue_bestfit/qe_bestfit)*180./3.1415 + zeros(len(l_bn))


##################
### Posteriors ###
##################
#Extracting the posteriors from the interval 
cred_interval_A = df_trace['A'].quantile(.25), df_trace['A'].quantile(.75)
cred_interval_B = df_trace['B'].quantile(.25), df_trace['B'].quantile(.75)
cred_interval_C = df_trace['C'].quantile(.25), df_trace['C'].quantile(.75)
cred_interval_D = df_trace['D'].quantile(.25), df_trace['D'].quantile(.75)

A_interval = trace.A[n_steps:][np.where((trace.A[n_steps:] < max(cred_interval_A))
                                             & (trace.A[n_steps:] > min(cred_interval_A)))]

B_interval = trace.B[n_steps:][np.where((trace.B[n_steps:] < max(cred_interval_B))
                                             & (trace.B[n_steps:] > min(cred_interval_B)))]

C_interval = trace.C[n_steps:][np.where((trace.C[n_steps:] < max(cred_interval_C))
                                             & (trace.C[n_steps:] > min(cred_interval_C)))]

D_interval = trace.D[n_steps:][np.where((trace.D[n_steps:] < max(cred_interval_D))
                                             & (trace.D[n_steps:] > min(cred_interval_D)))]

###############
### Figures ###
###############
font_size=50.0
label_size=50.
lw_components = 2.
lw_trace = 1.
ll = l_bn
alpha = 0.02
fig,(ax1,ax2,ax3,ax4) = plt.subplots(1,4,figsize=(20.0,4.),dpi=120)

for ii in range(0,len(A_interval)):
    qa = A_interval[ii] * fa 
    qe = B_interval[ii] * fe 
    q = qa + qe
    ax1.plot(ll,q,lw=lw_trace,color='red',alpha=alpha)

    ua = C_interval[ii] * fa
    ue = D_interval[ii] * fe 
    u = ua + ue
    ax2.plot(ll,u,lw=lw_trace,color='red',alpha=alpha)
    
    p = 100*np.sqrt(q*q + u*u)
    p_a = 100*np.sqrt(qa*qa + ua*ua) 
    p_e = 100*np.sqrt(qe*qe + ue*ue) 
    ax3.plot(ll,p,lw=lw_trace,color='red',alpha=alpha)
    ax3.plot(ll,p_a,lw=lw_trace,color='grey',alpha=alpha)
    ax3.plot(ll,p_e,lw=lw_trace,color='grey',alpha=alpha)
    
    pa = 0.5*np.arctan(u/q)*180./3.1592
    pa_a = 0.5*np.arctan(ua/qa)*180./3.1592
    pa_e = 0.5*np.arctan(ue/qe)*180./3.1592
    ax4.plot(ll,pa,lw=lw_trace,color='red',alpha=alpha)
    ax4.plot(ll,pa_a,lw=lw_trace,color='grey',alpha=alpha)
    ax4.plot(ll,pa_e,lw=lw_trace,color='grey',alpha=alpha)

#q
ax1.errorbar(l_obs,q_obs,yerr=qerr_obs,fmt='o',label='W51',color='blue')
ax1.plot(ll,q_bestfit,lw=lw_components,color='black',label='Model: total')
ax1.plot(ll,qa_bestfit,lw=lw_components,color='black',linestyle='-.',label='Model: absorptive component')
ax1.plot(ll,qe_bestfit,lw=lw_components,color='black',linestyle=':',label='Model: emissive component')

ax1.set_xlabel('Wavelength ($\mu$m)')
ax1.set_ylabel('q')
ax1.set_ylim([-0.07,0.07])
ax1.set_xlim([7,14])


#u
ax2.errorbar(l_obs,u_obs,yerr=uerr_obs,fmt='o',label='W51',color='blue')
ax2.plot(ll,u_bestfit,lw=lw_components,color='black',label='Model: total')
ax2.plot(ll,ua_bestfit,lw=lw_components,color='black',linestyle='-.',label='Model: absorptive component')
ax2.plot(ll,ue_bestfit,lw=lw_components,color='black',linestyle=':',label='Model: emissive component')


ax2.set_xlabel('Wavelength ($\mu$m)')
ax2.set_ylabel('u')
ax2.set_ylim([-0.07,0.07])
ax2.set_xlim([7,14])

#p
ax3.errorbar(l_obs,p_obs,yerr=perr_obs,fmt='o',label='W51',color='blue')
ax3.plot(ll,p_bestfit,lw=lw_components,color='black',label='Model: total')
ax3.plot(ll,p_a_bestfit,lw=lw_components,color='black',linestyle='-.',label='Model: absorptive component')
ax3.plot(ll,p_e_bestfit,lw=lw_components,color='black',linestyle=':',label='Model: emissive component')


ax3.set_xlabel('Wavelength ($\mu$m)')
ax3.set_ylabel('Degree of polarization (%)')
ax3.set_ylim([0,8])
ax3.set_xlim([7,14])

#pa
ax4.errorbar(l_obs,pa_obs,yerr=pa_err_obs,fmt='o',label='W51',color='blue')
ax4.plot(ll,pa_bestfit,lw=lw_components,color='black',label='Total Model')
ax4.plot(ll,pa_a_bestfit,lw=lw_components,color='black',linestyle='-.',label='absorptive component')
ax4.plot(ll,pa_e_bestfit,lw=lw_components,color='black',linestyle=':',label='emissive component')

ax4.set_xlabel('Wavelength ($\mu$m)')
ax4.set_ylabel('P.A. of polarization')
ax4.set_ylim([-90,90])
ax4.set_xlim([7,14])

ax1.legend(loc='lower left')


## Save Fig. to PDF and display
plt.savefig('W51_model.pdf')
os.system('open W51_model.pdf')
# Out:
# 0

# %%
#Measured values for analysis
#Min
qa_min = min(cred_interval_A) * fa 
qe_min = min(cred_interval_B) * fe
q_min = qa_min + qe_min
ua_min = min(cred_interval_C) * fa 
ue_min = min(cred_interval_D) * fe
u_min = ua_min + ue_min
p_min = 100*np.sqrt(q_min*q_min + u_min*u_min)
p_a_min = 100*np.sqrt(qa_min*qa_min + ua_min*ua_min) 
p_e_min = 100*np.sqrt(qe_min*qe_min + ue_min*ue_min)
pa_min = 0.5*np.arctan(u_min/q_min)*180./3.1592
pa_a_min = 0.5*np.arctan(ua_min/qa_min)*180./3.1592
pa_e_min = 0.5*np.arctan(ue_min/qe_min)*180./3.1592

#Max
qa_max = max(cred_interval_A) * fa 
qe_max = max(cred_interval_B) * fe
q_max = qa_max + qe_max
ua_max = max(cred_interval_C) * fa 
ue_max = max(cred_interval_D) * fe
u_max = ua_max + ue_max
p_max = 100*np.sqrt(q_max*q_max + u_max*u_max)
p_a_max = 100*np.sqrt(qa_max*qa_max + ua_max*ua_max) 
p_e_max = 100*np.sqrt(qe_max*qe_max + ue_max*ue_max)
pa_max = 0.5*np.arctan(u_max/q_max)*180./3.1592
pa_a_max = 0.5*np.arctan(ua_max/qa_max)*180./3.1592
pa_e_max = 0.5*np.arctan(ue_max/qe_max)*180./3.1592

# %% [markdown]
# Smith et al. (2000) found the following values from their fitting in Table 4:
# Emissive & Absorptive component:
#
#     P_a  = 6.0  +/- 0.3 %
#
#     PA_a = 136 +/- 2 degrees
#
#     P_e  = 2.8 +/- .3 %
#
#     PA_e = 36 +/- 3 degrees

# %%
#Maximum of he absorptive component
n_max = np.where(p_a_bestfit == max(p_a_bestfit))

print 'The values from the developed Bayesian approach are:'
print 'P_a =',round(max(p_a_bestfit),1),'+',round(max(p_a_bestfit)-max(p_a_max),1),'-',round(max(p_a_min)-max(p_a_bestfit),1),'%'
print 'PA_a =',round(pa_a_bestfit[0],0),'+',round(pa_a_max[0]-pa_a_bestfit[0],0),'-',round(pa_a_bestfit[0]-pa_a_min[0],0),'degrees'
print 'P_e =',round(p_e_bestfit[n_max],1),'+',round(p_e_max[n_max]-p_e_bestfit[n_max],1),'-',round(p_e_bestfit[n_max]-p_e_min[n_max],1),'%'
print 'PA_e =',round(pa_e_bestfit[0],0),'+',round(pa_e_bestfit[0]-pa_e_max[0],0),'-',round(pa_e_min[0]-pa_e_bestfit[0],0),'degrees'
# Out:
# The values from the developed Bayesian approach are:
# P_a = 7.3 + 0.6 - 0.6 %
# PA_a = -41.0 + 3.0 - 2.0 degrees
# P_e = 3.5 + 0.6 - 0.6 %
# PA_e = 43.0 + 3.0 - -85.0 degrees
